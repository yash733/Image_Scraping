# %% [markdown]
# Import all the necessary lib

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
from tqdm import tqdm
import time
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# #### Web_driver Initialization

# %%
chrome_options = Options()
service = Service('C:\\chromedriver\\chromedriver.exe')

# %%
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
driver.get('https://stock-pictures.netlify.app')

# %% [markdown]
# #### Auto Scroll

# %%
for scroll in tqdm(range(0,500000,1000)):
    driver.execute_script("window.scrollTo(0,"+str(scroll)+")")
    time.sleep(.5)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [04:21<00:00,  1.91it/s]

# %%
soup = bs(driver.page_source, 'html.parser')

# %% [markdown]
# #### Number of Images available

# %%
len(soup.find_all('div', class_ = 'container'))
# Out:
# 9104

# %% [markdown]
# #### Scraping the Data and forming Data Frame

# %%
data = []

for sp in tqdm(soup.find_all('div', class_ = 'container')):
    link = sp.find('img').get('src')                      # |-Remove-| part   
    tags = sp.find('span', class_ = 'tag-color').text[7:] # "Tags - "Clouds, Sky, Atmosphere, Blue Sky
    
    likes    = int(sp.find('div',class_ = 'likes-comments').find_all('span')[0].text[:-6])
    comments = int(sp.find('div',class_ = 'likes-comments').find_all('span')[1].text[:-9])
    
    #print(sp.find('div',class_ = 'tags').text[7:].strip())
    #break
    
    data.append([link, tags, likes, comments])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9104/9104 [00:00<00:00, 12650.13it/s]

# %%
data
# Out:
# [['https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg',
#   'Clouds, Sky, Atmosphere, Blue Sky',
#   196,
#   55],
#  ['https://cdn.pixabay.com/photo/2022/04/07/11/45/bird-7117346__340.jpg',
#   'Bird, Ornithology, Hummingbird',
#   76,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/02/28/15/28/sea-7039471__340.jpg',
#   'Sea, Rainbow, Rainfall, Subtropical',
#   282,
#   106],
#  ['https://cdn.pixabay.com/photo/2022/04/04/02/52/cherry-blossoms-7110279__340.jpg',
#   'Cherry Blossoms, Road, Japan, Sakura',
#   42,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/09/18/06/cape-marguerite-7121992__340.jpg',
#   'Cape Marguerite, Flower, Plant',
#   39,
#   15],
#  ['https://cdn.pixabay.com/photo/2021/11/13/23/06/tree-6792528__340.jpg',
#   'Relaxing Rest Under The Tree',
#   522,
#   108],
#  ['https://cdn.pixabay.com/photo/2022/04/07/02/56/cottontail-rabbit-7116707__340.jpg',
#   'Cottontail Rabbit, Wild Rabbit, Grass',
#   51,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/03/19/21/11/crocus-7079550__340.jpg',
#   'Crocus, Flowers, Spring, Plant',
#   135,
#   44],
#  ['https://cdn.pixabay.com/photo/2022/04/09/17/30/coffee-7121939__340.jpg',
#   'Coffee, Café, Vacation, Drink, Table',
#   26,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/03/25/19/24/waterfall-7091641__340.jpg',
#   'Waterfall, Fall, Epic, Nature, Light',
#   96,
#   21],
#  ['https://cdn.pixabay.com/photo/2021/08/25/20/42/field-6574455__340.jpg',
#   'Field, Morning, Sunrise, Dawn, Nature',
#   807,
#   131],
#  ['https://cdn.pixabay.com/photo/2022/04/04/18/03/bird-7111988__340.jpg',
#   'Bird, Robin, Birdwatching, Animal',
#   69,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/04/07/58/seedlings-7110591__340.jpg',
#   'Seedlings, Soil, Spring Flowers, Bloom',
#   42,
#   9],
#  ['https://cdn.pixabay.com/photo/2022/03/23/21/27/road-7087957__340.jpg',
#   'Road, Highway, Countryside, Hills',
#   53,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/03/27/15/03/cityscape-7095358__340.jpg',
#   'Cityscape, Monochrome, Bridge, City',
#   45,
#   13],
#  ['https://cdn.pixabay.com/photo/2022/03/25/17/54/sakura-7091532__340.jpg',
#   'Sakura, Cherry Blossoms, Spring, Water',
#   70,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/01/19/03/background-7105471__480.jpg',
#   'Background, Easter, Eggs, Template, Art',
#   5,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/01/31/12/46/bird-6983434__340.jpg',
#   'Bird, Indian Chat, Ornithology, Species',
#   171,
#   53],
#  ['https://cdn.pixabay.com/photo/2022/01/18/16/49/town-6947538__340.jpg',
#   'Town, Night, Winter, Village, Season',
#   109,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/09/17/42/flower-7121955__340.jpg',
#   'Flower, Viola, Pansy, Blossom, Bloom',
#   55,
#   36],
#  ['https://cdn.pixabay.com/photo/2021/08/30/21/29/port-6587129__340.jpg',
#   'Port, Lake, Architecture, Vacations',
#   276,
#   49],
#  ['https://cdn.pixabay.com/photo/2022/03/16/02/03/sunflowers-7071449__340.jpg',
#   'Sunflowers, Flowers, Plant',
#   54,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/03/28/18/41/coffee-7098126__340.jpg',
#   'Coffee, Spring, Flowers, Morning',
#   40,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/02/12/06/21/roys-peak-7008528__340.jpg',
#   'Roys Peak, Wanaka, Lake, Mountains',
#   69,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/11/21/21/14/mountain-6815304__340.jpg',
#   'Thank you, everyone. Thank you for many downloads and likes.',
#   197,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/08/22/15/48/nature-6565499__340.jpg',
#   'Nature, Beach, Outdoors, Exploration',
#   272,
#   150],
#  ['https://cdn.pixabay.com/photo/2022/03/03/11/18/nature-7045125__340.jpg',
#   'The Danish West Coast of Jutland. Shot during sunset.',
#   48,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/03/16/21/01/gentoo-penguin-7073391__340.jpg',
#   'Gentoo Penguin, Penguin, Bird, Animal',
#   93,
#   22],
#  ['https://cdn.pixabay.com/photo/2021/11/26/20/45/lantern-6826698__340.jpg',
#   'Lantern, Sea, Heaven, Beach, Water, Tree',
#   243,
#   31],
#  ['https://cdn.pixabay.com/photo/2022/04/03/05/03/easter-7108066__340.jpg',
#   'Easter, Spring, Easter Bunny',
#   17,
#   10],
#  ['https://cdn.pixabay.com/photo/2018/01/14/23/12/nature-3082832__340.jpg',
#   'green trees on brown rock formation on lake during daytime',
#   3098,
#   495],
#  ['https://cdn.pixabay.com/photo/2022/02/27/19/46/tourist-attraction-7037967__340.jpg',
#   'Tourist Attraction, Eiffel Tower, Travel',
#   83,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/04/07/22/23/menhir-7118382__480.jpg',
#   'Menhir, Stones, Clouds, Standing Stones',
#   64,
#   49],
#  ['https://cdn.pixabay.com/photo/2022/01/13/18/05/road-6935773__340.jpg',
#   'Road, Trees, Winter, Frost, Snow, Path',
#   133,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/10/07/03/bird-7122753__340.jpg',
#   'Bird, Woodpecker',
#   28,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/11/25/19/50/tape-6824489__340.jpg',
#   'Tape, Cassette, Music, Retro, Classic',
#   134,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/01/10/15/29/wind-mills-6928590__340.jpg',
#   'Wind Mills, Energy, Clouds, Power',
#   144,
#   101],
#  ['https://cdn.pixabay.com/photo/2022/02/15/07/27/travel-7014427__340.jpg',
#   'Travel, Tourism, Square, Tartini, Piran',
#   70,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/11/04/33/easter-eggs-7124718__340.jpg',
#   'Easter Eggs, Colored Eggs, Nest, Eggs',
#   29,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02/07/22/27/winter-7000429__340.jpg',
#   'Winter, Season, Nature, Outdoors, Travel',
#   111,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/11/09/40/glacier-7125386__340.jpg',
#   'Glacier, Dying Glaciers, Melting Glacier',
#   36,
#   27],
#  ['https://cdn.pixabay.com/photo/2021/11/01/21/31/forest-6761846__340.jpg',
#   'Forest, Jungle, Tropical, Green, Nature',
#   135,
#   22],
#  ['https://cdn.pixabay.com/photo/2022/02/05/08/13/tulip-6994245__340.jpg',
#   'Tulip, Flower, Bloom, Blossom, Petals',
#   92,
#   35],
#  ['https://cdn.pixabay.com/photo/2022/04/07/13/06/flowers-7117461__340.jpg',
#   'Flowers, Pink Flowers, Petals',
#   62,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02/22/03/22/passiflora-7027917__340.jpg',
#   'Passiflora, Passion Flower, Flower',
#   97,
#   66],
#  ['https://cdn.pixabay.com/photo/2021/11/02/21/57/prayer-6764197__340.jpg',
#   'Prayer, Faith, Religion, Hope, Blessing',
#   175,
#   57],
#  ['https://cdn.pixabay.com/photo/2022/04/09/10/13/galaxy-7121195__340.jpg',
#   'Galaxy, Space, Universe, Star, Cosmos',
#   45,
#   40],
#  ['https://cdn.pixabay.com/photo/2022/03/31/09/25/dragonfly-7102558__480.jpg',
#   'Dragonfly, Nature, Insect, Macro',
#   19,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/01/10/18/09/budapest-6928973__340.jpg',
#   'Budapest, Hungary, Architecture, Church',
#   107,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/03/16/11/27/trees-7072255__340.jpg',
#   'Trees, Forest, Leaves, Foliage, Magic',
#   66,
#   18],
#  ['https://cdn.pixabay.com/photo/2021/12/11/07/59/hotel-6862159__340.jpg',
#   'Das war bei meinem Aufenthalt in der Reha Klinik Klausenbach. Die liegt in Nordrach genauer in der Kolonie! Es wunderbarer Ort. Wie gemacht für die Erholung! Es gibt einen tollen Film mit Heike Makatsch als Dr. Hope Bridges Adams Lehmann als erste Ärztin 1880!',
#   94,
#   14],
#  ['https://cdn.pixabay.com/photo/2021/12/22/16/50/landscape-6887936__340.jpg',
#   'This is a tree plantation near the summit of Mt. Hiei (848m). The site is owned and managed by Enryaku-ji temple. The trees are Hinoki cypress, which is very useful for constructions and crafts. In the future, the woods are used for reconstruction of old temple buildings.',
#   160,
#   45],
#  ['https://cdn.pixabay.com/photo/2022/04/07/13/08/flowers-7117464__340.jpg',
#   'Flowers, Growth, Nature, Blossom, Bloom',
#   63,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02/04/10/31/cow-6992475__340.jpg',
#   'My baby (or babies) are due any day! ☺️',
#   155,
#   142],
#  ['https://cdn.pixabay.com/photo/2022/01/02/19/43/port-6910972__340.jpg',
#   'Port, Ship, Boat, Sweden, Sea',
#   89,
#   22],
#  ['https://cdn.pixabay.com/photo/2022/04/08/21/42/heron-7120365__340.jpg',
#   'Photographed on February 29, 2021 - the Pixabay license FORBIDS selling images as is on stock sites or elsewhere. Here is a link to the licence: https://pixabay.com/service/license/',
#   34,
#   51],
#  ['https://cdn.pixabay.com/photo/2021/11/01/13/58/leaf-6760484__340.jpg',
#   'Leaf, Nature, Autumn, Fall, Season, Leaf',
#   171,
#   53],
#  ['https://cdn.pixabay.com/photo/2021/08/27/18/50/water-6579313__340.jpg',
#   'Water, Trolltunga, Ringedalsvannet',
#   202,
#   45],
#  ['https://cdn.pixabay.com/photo/2021/12/01/18/17/cat-6838844__340.jpg',
#   'Cat, European Shorthair, Pet, Feline',
#   156,
#   49],
#  ['https://cdn.pixabay.com/photo/2022/01/26/20/43/baboon-6969935__340.jpg',
#   'Baboon, Animal, Wildlife, Gesture',
#   140,
#   41],
#  ['https://cdn.pixabay.com/photo/2022/04/10/19/28/savoy-7124124__340.jpg',
#   'Savoy, Cabbage, Vegetables, Carrots',
#   28,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/03/16/04/08/koi-fish-7071556__480.jpg',
#   'Koi Fish, Fish, Pond, Water, Koi',
#   54,
#   64],
#  ['https://cdn.pixabay.com/photo/2021/07/09/02/29/family-6398107__340.jpg',
#   'Family, Beach, People, Ocean, Family',
#   219,
#   57],
#  ['https://cdn.pixabay.com/photo/2022/02/26/21/47/elephant-7036431__340.jpg',
#   'Elephant, Baby Elephant, Animals',
#   104,
#   35],
#  ['https://cdn.pixabay.com/photo/2022/04/10/19/28/savoy-7124124__340.jpg',
#   'Savoy, Cabbage, Vegetables, Carrots',
#   24,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/04/10/10/08/ranunculus-7123057__340.jpg',
#   'Add a description (optional)',
#   25,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/08/17/33/great-cormorant-7119976__340.jpg',
#   'Great Cormorant, Bird',
#   36,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/10/19/07/flower-7124081__340.jpg',
#   'Flower, Daffodil, Petals, Plant',
#   21,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/01/28/18/46/sea-6975501__340.jpg',
#   'Sea, Waves, Storm, Sky, Clouds, Overcast',
#   102,
#   38],
#  ['https://cdn.pixabay.com/photo/2017/02/08/17/24/fantasy-2049567__340.jpg',
#   'Fantasy, Butterflies, Mushrooms, Forest',
#   3322,
#   536],
#  ['https://cdn.pixabay.com/photo/2022/03/15/15/19/child-7070570__340.jpg',
#   'Child, Boy, Flowers, Meadow, Cute, Kid',
#   43,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/06/12/18/grass-7115462__340.jpg',
#   'Grass, Plants, Oats, Ear, Barley',
#   46,
#   44],
#  ['https://cdn.pixabay.com/photo/2021/10/14/13/50/book-6709160__340.jpg',
#   'Book, Literature, Reading, Library',
#   130,
#   57],
#  ['https://cdn.pixabay.com/photo/2022/04/06/13/59/wood-anemones-7115637__340.jpg',
#   'Wood Anemones, Anemone, Buttercups',
#   46,
#   39],
#  ['https://cdn.pixabay.com/photo/2017/12/15/13/51/polynesia-3021072__340.jpg',
#   'white and red boat on beach during daytime',
#   2610,
#   499],
#  ['https://cdn.pixabay.com/photo/2022/04/03/09/30/flower-7108476__340.jpg',
#   'Flower, Bee, Pollination, Bloom, Insect',
#   50,
#   68],
#  ['https://cdn.pixabay.com/photo/2022/04/11/18/14/letter-box-7126374__480.jpg',
#   'Letter Box, Email Delivery, Post Office',
#   17,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/01/17/23/10/sunset-6945937__340.jpg',
#   'Calm Lake At Sunset',
#   59,
#   18],
#  ['https://cdn.pixabay.com/photo/2022/04/04/22/33/sunflowers-7112463__340.jpg',
#   'Illustration, sunflowers farming,',
#   72,
#   77],
#  ['https://cdn.pixabay.com/photo/2022/02/19/21/46/beach-7023446__340.jpg',
#   'Beach, Sand, Sea, North Sea, Winter',
#   30,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/01/13/16/37/trees-6935614__340.jpg',
#   'Trees, Nature, Winter, Season, Outdoors',
#   90,
#   18],
#  ['https://cdn.pixabay.com/photo/2022/03/02/14/25/flower-7043267__340.jpg',
#   'Flower, Rose, Bloom, Blossom, Botany',
#   107,
#   91],
#  ['https://cdn.pixabay.com/photo/2021/12/27/11/55/winter-6897046__340.jpg',
#   'Winter, Frost, Nature, Texture, Macro',
#   113,
#   32],
#  ['https://cdn.pixabay.com/photo/2021/12/28/14/30/bird-6899457__340.jpg',
#   'Bird, Blackbird, Ornithology, Species',
#   109,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/10/14/27/trees-7123499__340.jpg',
#   'Trees, Rural, Clouds, Nature, Landscape',
#   14,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/01/16/20/38/coffee-6943139__340.jpg',
#   'Coffee, Pencils, Eraser, Office',
#   69,
#   9],
#  ['https://cdn.pixabay.com/photo/2021/07/18/04/00/lotus-6474572__340.jpg',
#   'Lotus, Flower, Lotus Flower, Pink Flower',
#   279,
#   45],
#  ['https://cdn.pixabay.com/photo/2022/04/01/15/31/bus-7105041__340.jpg',
#   'Es sind noch Plätze frei…',
#   43,
#   34],
#  ['https://cdn.pixabay.com/photo/2022/01/21/19/21/crocus-6955548__340.jpg',
#   'Crocus, Flowers, Plants, Purple Crocus',
#   77,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/04/11/09/18/birds-7125333__340.jpg',
#   'Taken in March 21, 2022',
#   16,
#   7],
#  ['https://cdn.pixabay.com/photo/2021/12/12/22/48/mountain-6867146__340.jpg',
#   'Mountain, Summit, Forest, Winter, Clouds',
#   82,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/04/10/07/33/ice-cream-cone-7122797__340.jpg',
#   'Ice Cream Cone, Ice Squirrel, Flower',
#   16,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/09/09/29/flower-7121113__480.jpg',
#   'Flower, Magnolia, Tree, Spring Flowers',
#   8,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/06/09/46/flowers-7115215__340.jpg',
#   'Flowers, Bouquet, Garden',
#   47,
#   26],
#  ['https://cdn.pixabay.com/photo/2022/03/04/09/02/winter-7046891__340.jpg',
#   'Help Ukraine! Stop the war!',
#   56,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/03/08/33/jay-7108357__340.jpg',
#   'Jay, Bird, Animal, Snow, Winter',
#   62,
#   48],
#  ['https://cdn.pixabay.com/photo/2022/04/09/07/14/dungeon-7120925__340.jpg',
#   'Built in 1300-1400, the former Augustinian (Les Augustins, in French) convent in Toulouse (France) has become a museum.',
#   17,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/11/09/16/birds-7125327__340.jpg',
#   'Birds, Egyptian Goslings, Waterfowl',
#   15,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/04/06/08/16/peach-blossom-7115083__340.jpg',
#   'Peach Blossom, Flowers, Branch, Tree',
#   41,
#   58],
#  ['https://cdn.pixabay.com/photo/2021/12/01/15/32/happy-new-year-6838276__340.jpg',
#   'Happy New Year, 2022, Regards, New Year',
#   45,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/04/03/17/48/flowers-7109567__340.jpg',
#   'Flowers, Botany, Quince',
#   55,
#   47],
#  ['https://cdn.pixabay.com/photo/2016/11/29/05/45/astronomy-1867616__340.jpg',
#   'Astronomy, Bright, Constellation, Dark',
#   2989,
#   484],
#  ['https://cdn.pixabay.com/photo/2022/02/14/10/35/flowers-7012876__340.jpg',
#   'Flowers, Bloom, Botany, Blossom, Nature',
#   43,
#   13],
#  ['https://cdn.pixabay.com/photo/2021/08/23/08/28/path-6567149__340.jpg',
#   'Path, Rural, Nature, Road, Countryside',
#   178,
#   36],
#  ['https://cdn.pixabay.com/photo/2022/02/14/06/54/bird-7012586__340.jpg',
#   'Bird, Ibis, Spiny Ibis, Ornithology',
#   141,
#   102],
#  ['https://cdn.pixabay.com/photo/2021/08/27/10/16/baby-6578335__340.jpg',
#   'Baby, Girl, Portrait, Child, Daughter',
#   179,
#   54],
#  ['https://cdn.pixabay.com/photo/2021/12/20/15/01/christmas-tree-6883263__340.jpg',
#   'Christmas Tree, Ornaments, Christmas',
#   147,
#   99],
#  ['https://cdn.pixabay.com/photo/2021/09/30/18/10/sunrise-6670717__340.jpg',
#   'Sunrise, Mountains, Fog, Swabian Jura',
#   140,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/05/22/54/giant-lily-7114496__480.jpg',
#   'Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…',
#   47,
#   32],
#  ['https://cdn.pixabay.com/photo/2022/04/06/22/27/postcard-7116453__340.jpg',
#   'Postcard, Greeting Card, Peacocks, Birds',
#   31,
#   36],
#  ['https://cdn.pixabay.com/photo/2022/01/25/04/42/bird-6965228__340.jpg',
#   'Bird, Great Egret, Ornithology, Species',
#   89,
#   47],
#  ['https://cdn.pixabay.com/photo/2022/01/10/16/30/flowers-6928749__340.jpg',
#   'Flowers, Grass, Coast, Cliff, Beach, Sea',
#   79,
#   12],
#  ['https://cdn.pixabay.com/photo/2021/12/18/17/11/flower-6879399__340.jpg',
#   'Flower, Dandelion, Wildflower, Seeds',
#   88,
#   14],
#  ['https://cdn.pixabay.com/photo/2021/12/14/20/21/book-6871220__340.jpg',
#   'Book, Page, Man, Stop, Shades, Paper',
#   80,
#   49],
#  ['https://cdn.pixabay.com/photo/2021/08/23/07/38/castle-6566978__340.jpg',
#   'Castle, Monument, Park, Building',
#   159,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/05/15/11/birds-7113827__340.jpg',
#   'Birds, Greylag Goose, Ornithology',
#   41,
#   28],
#  ['https://cdn.pixabay.com/photo/2022/04/08/19/05/hyacinth-7120098__340.jpg',
#   'Hyacinth, Flowers, Spring, Nature',
#   15,
#   9],
#  ['https://cdn.pixabay.com/photo/2022/04/05/00/25/bokeh-7112555__340.jpg',
#   'Bokeh, Light, Background, Pattern, Art',
#   27,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/02/10/53/easter-7106722__340.jpg',
#   'Easter, Easter Bunny, Easter Decoration',
#   55,
#   87],
#  ['https://cdn.pixabay.com/photo/2021/11/26/17/26/desert-6826299__340.jpg',
#   'Desert, Sand, Dunes, Dubai, Native',
#   48,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/04/03/09/04/pforphoto-7108433__340.jpg',
#   'The Piano…',
#   35,
#   25],
#  ['https://cdn.pixabay.com/photo/2020/04/25/12/14/tech-5090539__340.jpg',
#   'Tech, Circle, Technology, Abstract',
#   404,
#   109],
#  ['https://cdn.pixabay.com/photo/2022/04/06/09/46/flowers-7115217__340.jpg',
#   'Flowers, Hyacinth, Garden',
#   40,
#   28],
#  ['https://cdn.pixabay.com/photo/2022/03/28/05/17/cherry-blossoms-7096607__340.jpg',
#   'Cherry Blossoms, Pink Flowers, Sakura',
#   61,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/08/12/12/coffee-7119373__480.jpg',
#   'Coffee, Template, Coffee Stain, Dirty',
#   26,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/02/02/13/50/happy-easter-6988491__340.jpg',
#   'Happy Easter, Spring, Decoration, Theme',
#   29,
#   10],
#  ['https://cdn.pixabay.com/photo/2021/12/12/01/15/lotus-6863937__340.jpg',
#   'Lotus, Flowers, Pond, Lily Pads',
#   101,
#   23],
#  ['https://cdn.pixabay.com/photo/2022/01/21/07/21/ring-tailed-lemur-6954076__340.jpg',
#   'Ring Tailed Lemur, Lemur, Group, Cub',
#   160,
#   115],
#  ['https://cdn.pixabay.com/photo/2022/04/07/04/03/bird-7116757__340.jpg',
#   'El estornino pinto, o estornino común, (Sturnus vulgaris)\u200b es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires.',
#   23,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/10/11/09/04/nature-6699893__340.jpg',
#   'Nature, Spruce, Evergreen, Branches',
#   99,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/04/08/07/22/tablets-7118912__340.jpg',
#   'Tablets, Drugs, Powder',
#   22,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/01/17/08/27/white-flowers-6944139__340.jpg',
#   'White Flowers, Flowers, Nature',
#   49,
#   11],
#  ['https://cdn.pixabay.com/photo/2021/09/14/14/46/cologne-6624212__340.jpg',
#   'Cologne, Cathedral, Bridge, Night, River',
#   98,
#   27],
#  ['https://cdn.pixabay.com/photo/2015/12/01/20/28/road-1072823__340.jpg',
#   'Road, Forest, Fall, Autumn, Season',
#   5214,
#   1126],
#  ['https://cdn.pixabay.com/photo/2022/04/08/06/13/bird-7118767__340.jpg',
#   'Bird, Geese, Ornithology, Species, Fauna',
#   23,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/04/15/16/flowers-7111580__340.jpg',
#   'Foto von Ende März 2022',
#   27,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/10/10/20/33/mehtab-bagh-6698669__340.jpg',
#   'Mehtab Bagh, India, Taj Mahal, Temple',
#   73,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/09/05/35/tulips-7120798__340.jpg',
#   'Tulips, Flower, Plant, Flora',
#   10,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/04/06/59/canada-goose-7110494__340.jpg',
#   'Canada Goose, Goose, Swim, Water Bird',
#   57,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/03/02/19/27/earth-7043847__340.jpg',
#   'Earth, Planet, Homeland, Mankind',
#   36,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/04/07/04/04/starling-7116759__480.jpg',
#   'El estornino pinto, o estornino común, (Sturnus vulgaris)\u200b es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires.',
#   22,
#   17],
#  ['https://cdn.pixabay.com/photo/2022/03/28/20/47/house-7098314__340.jpg',
#   'Composition, lake view',
#   81,
#   81],
#  ['https://cdn.pixabay.com/photo/2022/04/08/17/33/bird-7119983__340.jpg',
#   'Bird, Blackbird, Songbird, Fauna, Animal',
#   18,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/10/10/04/bird-7123044__340.jpg',
#   'Durian Redstart. In Japan, it is a winter bird, wintering in regions without snow cover and inhabiting flat to low mountain farmlands, residential areas, parks, and riverbanks.',
#   10,
#   6],
#  ['https://cdn.pixabay.com/photo/2021/11/09/07/29/newborn-6780840__340.jpg',
#   'Newborn, Baby, Costume, Sleeping',
#   91,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/04/02/20/46/cat-7107728__340.jpg',
#   'Cat, Grass, Backyard, Outdoors, Kitten',
#   54,
#   36],
#  ['https://cdn.pixabay.com/photo/2021/06/22/16/39/arch-6356637__340.jpg',
#   'Arch, Alley, Street, Road, Eiffel Tower',
#   261,
#   51],
#  ['https://cdn.pixabay.com/photo/2022/03/21/16/12/blackbird-7083494__340.jpg',
#   'Blackbird, Bird, Animal, Worm, Eating',
#   70,
#   51],
#  ['https://cdn.pixabay.com/photo/2022/04/06/10/08/dog-7115247__340.jpg',
#   'Dog, Golden Retriever, Water, Swim, Lake',
#   33,
#   22],
#  ['https://cdn.pixabay.com/photo/2022/04/09/21/10/clouds-7122287__340.jpg',
#   'Clouds, Sky, Atmosphere, Grey Clouds',
#   5,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/12/12/02/flowers-7127847__340.jpg',
#   'Flowers, Spring, Seasonal, Nature, Bloom',
#   17,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/03/31/14/12/flower-7103109__340.jpg',
#   'Flower, Liverflower, Early Bloomer',
#   74,
#   57],
#  ['https://cdn.pixabay.com/photo/2021/05/29/17/35/car-6293917__340.jpg',
#   'Car, Beach, Sunset, Desktop Wallpaper',
#   37,
#   7],
#  ['https://cdn.pixabay.com/photo/2021/10/23/03/35/mountain-6734031__340.jpg',
#   'Mountain, Summit, Snow, Winter',
#   85,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/04/08/11/47/daffodil-7119341__340.jpg',
#   'Aufgenommen am 5.3.2022',
#   29,
#   22],
#  ['https://cdn.pixabay.com/photo/2021/08/29/08/49/petit-minou-lighthouse-6582717__340.jpg',
#   'Petit Minou Lighthouse, Lighthouse, Sea',
#   120,
#   29],
#  ['https://cdn.pixabay.com/photo/2018/01/30/22/50/forest-3119826__480.jpg',
#   'Forest, Twilight, Nature, Trees, Woods',
#   1417,
#   188],
#  ['https://cdn.pixabay.com/photo/2022/04/07/17/32/european-shorthair-7118037__340.jpg',
#   'European Shorthair, Cat, Pet, Animal',
#   18,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/04/11/19/35/easter-bunny-7126487__340.jpg',
#   'Easter Bunny, Easter, Easter Festival',
#   9,
#   7],
#  ['https://cdn.pixabay.com/photo/2022/03/28/17/19/mountains-7097981__340.jpg',
#   'Mountains, Meadow, Cabin, Clouds, Herb',
#   63,
#   55],
#  ['https://cdn.pixabay.com/photo/2021/07/27/16/23/buildings-6497337__340.jpg',
#   'Buildings, Town, Road, Hills, Sunset',
#   132,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/03/14/20/54/city-7069010__340.jpg',
#   'City, Travel, Tourism, Mexico City',
#   19,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/09/09/29/magnolia-7121115__340.jpg',
#   'Magnolia, Flower, Tree, Spring Flowers',
#   2,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/10/19/17/donkey-7124096__340.jpg',
#   'Donkey, Animal, Draft Animal, Mammal',
#   10,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/08/11/46/weave-7119337__340.jpg',
#   'Aufgenommen am 20.3.2021',
#   27,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/09/14/54/fields-7121593__340.jpg',
#   'Fields, Nature, Landscape, Meadow, Rural',
#   14,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/08/13/45/flowers-7119514__340.jpg',
#   'This is now the season for Cherry blossoms in Japan. Have you ever heard of “hanami”? We sit under the cherry trees and eat and drink with our friends.',
#   14,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/03/19/08/45/alley-7078098__340.jpg',
#   'In einem kleinen Städtchen ...',
#   57,
#   33],
#  ['https://cdn.pixabay.com/photo/2022/04/06/06/30/drake-7114868__340.jpg',
#   'Drake, Waterbird, Wings',
#   20,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/11/17/10/57/pine-cone-6803226__340.jpg',
#   'Pine Cone, Fir Green, Fir Branch',
#   126,
#   43],
#  ['https://cdn.pixabay.com/photo/2021/10/15/22/59/heron-6713611__340.jpg',
#   'Heron, Great Egret, River, Lake, Pond',
#   163,
#   127],
#  ['https://cdn.pixabay.com/photo/2021/10/08/06/45/seagulls-6690361__340.jpg',
#   'Seagulls, Birds, Nature, Ocean, Sea, Sky',
#   121,
#   30],
#  ['https://cdn.pixabay.com/photo/2021/07/22/21/55/mountains-6486093__480.jpg',
#   'Mountains, Nature, Tourism, Hike, Alpine',
#   122,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/04/08/43/road-7110643__340.jpg',
#   'Road, Mountain, Countryside, Landscape',
#   29,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/11/11/16/29/tree-6786654__340.jpg',
#   'Tree, Leaves, Autumn, Season, Nature',
#   89,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/03/23/17/41/fantasy-7087606__340.jpg',
#   'Fantasy, Elf, Light, Plants, Bird Magic',
#   32,
#   17],
#  ['https://cdn.pixabay.com/photo/2022/03/12/09/27/couple-7063784__340.jpg',
#   'Couple, Meadow, Walking, Nature, Sunset',
#   17,
#   5],
#  ['https://cdn.pixabay.com/photo/2016/12/16/15/25/christmas-1911637__340.jpg',
#   'Christmas, Background, Flat Lay',
#   2860,
#   460],
#  ['https://cdn.pixabay.com/photo/2022/04/06/17/40/blackthorn-7116000__340.jpg',
#   'Blackthorn, Sloe, Winter, Prunus Spinosa',
#   23,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/08/27/19/55/boat-6579441__340.jpg',
#   'Boat, River, Forest, Landscape, Woods',
#   145,
#   26],
#  ['https://cdn.pixabay.com/photo/2022/04/09/18/25/walnuts-7122043__340.jpg',
#   'Walnuts, Nuts, Food, Healthy, Nutrition',
#   11,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/12/04/46/climate-change-7127153__340.jpg',
#   'Climate Change, Protest, People',
#   12,
#   9],
#  ['https://cdn.pixabay.com/photo/2021/08/08/15/45/mountains-6531264__340.jpg',
#   'Mountains, Sunset, Germany, Fortress',
#   116,
#   26],
#  ['https://cdn.pixabay.com/photo/2021/11/27/18/28/candles-6828695__340.jpg',
#   'Candles, Candlelight, Christmas',
#   122,
#   60],
#  ['https://cdn.pixabay.com/photo/2022/02/19/08/48/flower-7022112__340.jpg',
#   'Flower, Butterfly, Fantasy, Spring',
#   97,
#   72],
#  ['https://cdn.pixabay.com/photo/2022/04/04/10/39/australian-wood-duck-7110865__340.jpg',
#   'Australian Wood Duck, Duck, Bird',
#   45,
#   44],
#  ['https://cdn.pixabay.com/photo/2021/10/04/16/42/dog-6680642__340.jpg',
#   'Dog, Puppy, Pet, Cute, Doggy, Animal',
#   89,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/03/31/05/07/cherry-blossom-7102224__340.jpg',
#   'Cherry Blossom, Spring, Nature, Flowers',
#   57,
#   48],
#  ['https://cdn.pixabay.com/photo/2021/12/26/19/36/christmas-tree-6895765__480.jpg',
#   'Christmas Tree, Holiday, Season',
#   54,
#   11],
#  ['https://cdn.pixabay.com/photo/2021/07/26/22/04/sea-shell-6495338__340.jpg',
#   'Sea Shell, Giant Conch',
#   206,
#   95],
#  ['https://cdn.pixabay.com/photo/2021/02/05/18/05/paper-5985445__340.jpg',
#   'Paper, Crumpled, Texture, Shadows, Fold',
#   186,
#   38],
#  ['https://cdn.pixabay.com/photo/2022/03/31/14/16/bee-7103114__340.jpg',
#   'Bee, Pollination, Entomology, Macro',
#   57,
#   41],
#  ['https://cdn.pixabay.com/photo/2022/04/06/05/26/butterfly-7114816__340.jpg',
#   'Butterfly, Aurora Butterfly, Meadow',
#   25,
#   16],
#  ['https://cdn.pixabay.com/photo/2021/12/02/13/02/candles-6840499__340.jpg',
#   '4 Weihnachtskerzen',
#   70,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/06/14/27/mute-swan-7115661__340.jpg',
#   'Add a description (optional)',
#   40,
#   33],
#  ['https://cdn.pixabay.com/photo/2022/04/09/06/20/tulip-7120843__340.jpg',
#   'Tulip, Spring, Flowering, Flower',
#   9,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/03/22/19/29/town-7085835__340.jpg',
#   'Town, Countryside, Nature, Landscape',
#   69,
#   62],
#  ['https://cdn.pixabay.com/photo/2022/04/11/07/30/birds-7124996__340.jpg',
#   'El Hornero ( Furnarius rufus ) es una especie de ave paseriforme perteneciente a la familia de los furnáridos, y compone, junto con otras cinco especies el género Furnarius. El hornero es endémico de Sudamérica meridional y es el ave nacional de la República Argentina.',
#   7,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/04/05/12/00/cherry-blossom-7113414__340.jpg',
#   'Cherry Blossom, Flowers, Spring, Sakura',
#   32,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/07/23/58/fantasy-7118471__340.jpg',
#   'Fantasy, No Truth, Silence, Bound',
#   19,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/03/01/09/15/salad-7040875__340.jpg',
#   'Salad, Fruit, Berry, Healthy, Vitamins',
#   30,
#   10],
#  ['https://cdn.pixabay.com/photo/2021/11/01/08/39/petit-minou-lighthouse-6759731__340.jpg',
#   'Petit Minou Lighthouse, Lighthouse, Sea',
#   61,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/11/19/05/easter-bunny-7126452__340.jpg',
#   'Easter Bunny, Easter, Easter Decorations',
#   12,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/04/09/22/33/bird-7122361__340.jpg',
#   'Bird, Heron, Ornithology, Species, Fauna',
#   12,
#   7],
#  ['https://cdn.pixabay.com/photo/2022/04/01/08/57/shepherds-purses-7104384__480.jpg',
#   "Shepherd'S-Purses, Capsella, Grass",
#   45,
#   40],
#  ['https://cdn.pixabay.com/photo/2022/04/07/11/55/bernkastel-kues-7117366__340.jpg',
#   'Bernkastel-Kues, Germany, Cityscape',
#   20,
#   10],
#  ['https://cdn.pixabay.com/photo/2021/04/21/13/20/cherry-blossoms-6196363__340.jpg',
#   'Cherry Blossoms, Sakura, Flowers',
#   406,
#   211],
#  ['https://cdn.pixabay.com/photo/2022/04/11/20/31/purple-flowers-7126569__340.jpg',
#   'Purple Flowers, Flowers, Pasqueflowers',
#   5,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/03/02/01/07/cyberpunk-6061251__340.jpg',
#   'Cyberpunk, Street, City, Platform',
#   220,
#   32],
#  ['https://cdn.pixabay.com/photo/2022/03/29/12/31/leaves-7099402__340.jpg',
#   'Leaves, Growth, Botany, Nature, Plant',
#   61,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/04/10/10/34/flower-7123108__340.jpg',
#   'Flower, Petals, Baby Rose',
#   8,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/05/09/23/birds-7048729__340.jpg',
#   'Birds, Duck, Ornithology, Species, Fauna',
#   103,
#   79],
#  ['https://cdn.pixabay.com/photo/2022/04/10/18/04/robin-7123932__340.jpg',
#   'Robin, Bird, Beak, Feathers, Plumage',
#   4,
#   2],
#  ['https://cdn.pixabay.com/photo/2018/06/13/18/20/waves-3473335__340.jpg',
#   'Waves, Sea, Ocean, Beach, Blue Water',
#   1807,
#   310],
#  ['https://cdn.pixabay.com/photo/2022/03/05/22/13/daffodil-7050408__340.jpg',
#   'Daffodil, Flower, Yellow Flower, Petals',
#   87,
#   73],
#  ['https://cdn.pixabay.com/photo/2022/04/09/16/26/bird-7121805__340.jpg',
#   'Bird, Yellow Warbler, Ornithology',
#   3,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/11/20/01/leopard-7126525__340.jpg',
#   'Leopard, Animal, Mammal, Big Cat',
#   7,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/01/28/21/10/honeybee-6975865__340.jpg',
#   'Honeybee, Sunflower, Pollination, Bee',
#   51,
#   11],
#  ['https://cdn.pixabay.com/photo/2020/02/08/14/36/trees-4830285__340.jpg',
#   'Trees, Winter, Snow, White, Cold, Nature',
#   442,
#   106],
#  ['https://cdn.pixabay.com/photo/2021/10/29/14/27/nature-6752035__480.jpg',
#   'High in the French alps. Climbers walk the steep ridge of the valley blanche. The mountains are as dangerous as they are beautiful 👀 Chamonix Mont Blanc',
#   85,
#   16],
#  ['https://cdn.pixabay.com/photo/2021/08/15/14/47/couple-6548045__340.jpg',
#   'Couple, Silhouette, Love, Relationship',
#   76,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/11/25/09/28/amsterdam-6823002__340.jpg',
#   'Amsterdam, Dam Square, Child, Pigeons',
#   91,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/09/12/11/duck-7121326__340.jpg',
#   'Duck, Bird, Beak, Feathers, Plumage',
#   7,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/09/21/11/rice-7122289__340.jpg',
#   'Rice, Tomatoes, Food, Grain, Dish, Table',
#   7,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/08/08/15/01/trading-6531134__340.jpg',
#   'Trading, Blockchain, Cryptocurrency',
#   38,
#   7],
#  ['https://cdn.pixabay.com/photo/2021/08/14/20/44/stones-6546233__340.jpg',
#   'Stones, Rock, Balance, Balanced Rocks',
#   109,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/03/11/02/57/mountain-6086083__340.jpg',
#   'Mountain, Snow, Sunrise, Peak, Summit',
#   286,
#   71],
#  ['https://cdn.pixabay.com/photo/2021/08/31/18/51/forest-6589852__340.jpg',
#   'Forest, Nature, Trees, Woods, Outdoors',
#   102,
#   13],
#  ['https://cdn.pixabay.com/photo/2022/04/03/14/25/bird-7109091__340.jpg',
#   'Bird, Robin, Ornithology, Species, Fauna',
#   36,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/08/15/01/mushrooms-7119658__340.jpg',
#   'Mushrooms, Fungi, Mycology, Forest Floor',
#   10,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/07/10/19/crafting-7117240__340.jpg',
#   'Crafting, Daisies, Vintage Aesthetic',
#   9,
#   3],
#  ['https://cdn.pixabay.com/photo/2020/07/27/14/34/forest-5442598__340.jpg',
#   'Forest, Stars, Mountains, Night Sky',
#   411,
#   50],
#  ['https://cdn.pixabay.com/photo/2022/01/03/21/08/street-6913633__340.jpg',
#   'Sunset Street in Bavarian Alps',
#   35,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/04/11/15/32/petals-7126056__480.jpg',
#   'Petals, Tree, Cherry, Garden, Blossom',
#   7,
#   5],
#  ['https://cdn.pixabay.com/photo/2016/11/29/13/37/christmas-1869902__340.jpg',
#   'Christmas, Christmas Tree, Presents',
#   1184,
#   292],
#  ['https://cdn.pixabay.com/photo/2022/03/27/10/19/squill-7094638__340.jpg',
#   'Squill, Flowers, Plant, Scilla',
#   66,
#   51],
#  ['https://cdn.pixabay.com/photo/2022/04/05/15/13/soap-bubbles-7113833__340.jpg',
#   'Soap Bubbles, Colour, Macro, Pattern',
#   21,
#   16],
#  ['https://cdn.pixabay.com/photo/2021/07/21/12/22/lavenders-6482952__340.jpg',
#   'Lavenders, Flowers, Lavender Field',
#   158,
#   36],
#  ['https://cdn.pixabay.com/photo/2022/04/03/12/45/flowers-7108857__340.jpg',
#   "Flowers, Lucile'S Glory Of The Snow",
#   39,
#   25],
#  ['https://cdn.pixabay.com/photo/2021/11/17/17/03/roses-6804169__340.jpg',
#   'Roses, Flowers, Yellow Flowers',
#   96,
#   25],
#  ['https://cdn.pixabay.com/photo/2022/02/07/15/22/fuel-6999638__340.jpg',
#   'Fuel, Gas Station, Refueling, Gas',
#   9,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/04/09/16/46/peace-7121863__340.jpg',
#   'Peace, Peace Sign, Against War, Ukraine',
#   13,
#   8],
#  ['https://cdn.pixabay.com/photo/2022/03/20/10/50/lake-7080525__340.jpg',
#   'Lake, Mountains, Nature, Dusk, To Travel',
#   72,
#   62],
#  ['https://cdn.pixabay.com/photo/2022/04/06/08/13/peach-blossom-7115080__340.jpg',
#   'Peach Blossom, Flowers, Branch, Tree',
#   18,
#   18],
#  ['https://cdn.pixabay.com/photo/2021/07/29/09/54/honey-bee-6506809__340.jpg',
#   'Honey Bee, Bee, Flowers, Insect, Tansy',
#   106,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/08/20/38/flower-7120281__340.jpg',
#   'Flower, Anemone, Spring, Blue, Nature',
#   10,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/09/06/50/magnolia-7120880__340.jpg',
#   'Magnolia, Bud, Flower, Plant, Shrub',
#   8,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/05/23/11/giant-lily-7114512__340.jpg',
#   'Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…',
#   29,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/07/18/17/11/rufous-6476117__480.jpg',
#   'Rufous, Bird, Hummingbird, Flight, Wings',
#   192,
#   45],
#  ['https://cdn.pixabay.com/photo/2021/06/20/08/35/ginkgo-6350293__340.jpg',
#   'Ginkgo, Leaf, Dew, Dewdrops, Raindrops',
#   125,
#   32],
#  ['https://cdn.pixabay.com/photo/2022/01/15/15/30/lantern-6939870__340.jpg',
#   'Lantern, Festival, Decoration',
#   35,
#   9],
#  ['https://cdn.pixabay.com/photo/2021/11/17/15/07/paris-6803796__340.jpg',
#   'Paris, City, Cloudy Day, Stormy Day',
#   64,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/04/09/15/12/animal-7121622__340.jpg',
#   'Animal, Hamadryas Baboon, Baboon',
#   5,
#   1],
#  ['https://cdn.pixabay.com/photo/2018/10/01/09/21/pets-3715733__340.jpg',
#   'Pets, Cute, Cat, Dog, Cute Wallpaper',
#   703,
#   182],
#  ['https://cdn.pixabay.com/photo/2020/05/25/17/03/travel-5219496__340.jpg',
#   'Travel, Airport, Boarding Pass, Boarding',
#   161,
#   34],
#  ['https://cdn.pixabay.com/photo/2022/04/07/21/46/valley-7118324__340.jpg',
#   'Portret van de lente',
#   10,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/04/06/10/57/ribbon-7115324__340.png',
#   'Ribbon, Bow, Gift, Decoration, Colorful',
#   13,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/01/07/41/cows-7104262__340.jpg',
#   'Cows, Cattle, Livestock, Farm Animals',
#   47,
#   40],
#  ['https://cdn.pixabay.com/photo/2022/04/01/17/02/glory-of-the-snow-7105247__340.jpg',
#   'Photographed on 29-03-22 in the Amstelpark.',
#   47,
#   59],
#  ['https://cdn.pixabay.com/photo/2022/04/08/06/53/animal-7118858__340.jpg',
#   'Animal, Dog, Canine, Mammal, Breed, Pet',
#   11,
#   7],
#  ['https://cdn.pixabay.com/photo/2022/03/09/15/58/tulips-7058127__340.jpg',
#   'Tulips, Flowers, Blossom, Petals, Bloom',
#   107,
#   90],
#  ['https://cdn.pixabay.com/photo/2022/04/11/22/08/meadowsweet-7126754__340.jpg',
#   'Meadowsweet, Flowers, Plant',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/01/20/01/23/floral-background-6951261__480.jpg',
#   'Floral Background, Scrapbooking',
#   80,
#   73],
#  ['https://cdn.pixabay.com/photo/2022/04/05/15/08/nature-7113818__340.jpg',
#   'Nature, Sea, Sunset, Water, Mood, Ocean',
#   24,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/04/08/15/42/nutrition-7119739__340.jpg',
#   'Nutrition, Market, Corn, Organic, Fresh',
#   11,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/03/20/09/38/flower-7080355__340.jpg',
#   'Flower, Humming-Bird, Bird, Orchid',
#   49,
#   37],
#  ['https://cdn.pixabay.com/photo/2021/08/23/11/06/nature-6567542__340.jpg',
#   'Nature, Outdoors, Travel, Exploration',
#   78,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/08/11/39/fire-fighters-7119324__340.jpg',
#   'Fire Fighters, Fire Truck, Fire Fighting',
#   19,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/07/05/23/orange-flower-7116831__340.jpg',
#   'Orange Flower, Garden, Flower, Nature',
#   12,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/01/05/52/dog-7104086__340.jpg',
#   'Die Badesaison ist eröffnet 😊',
#   39,
#   33],
#  ['https://cdn.pixabay.com/photo/2022/03/31/11/07/lion-7102789__340.jpg',
#   'Lion, Animal, Roar, Teeth, Mammal, Cats',
#   24,
#   28],
#  ['https://cdn.pixabay.com/photo/2021/11/06/12/27/drops-6773267__340.jpg',
#   'Drops, Water Drops, Trypophobia',
#   84,
#   39],
#  ['https://cdn.pixabay.com/photo/2021/11/18/22/17/butterfly-6807529__340.jpg',
#   'Butterfly, Insect, Winged Insect',
#   78,
#   16],
#  ['https://cdn.pixabay.com/photo/2021/07/14/12/01/poppies-6465890__340.jpg',
#   'Poppies, Flowers, Buds, Field',
#   141,
#   35],
#  ['https://cdn.pixabay.com/photo/2021/11/25/07/18/beach-6822823__340.jpg',
#   'Beach, Ocean, Sea, Spain, Water, Nature',
#   65,
#   6],
#  ['https://cdn.pixabay.com/photo/2021/12/17/17/00/butterfly-6876992__340.jpg',
#   'Butterfly, Pollination, Nature, Flower',
#   49,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/08/17/05/bird-7119927__340.jpg',
#   'Bird, Owl, Ornithology, Species, Fauna',
#   10,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/30/15/31/mountains-7101380__340.jpg',
#   'Mountains, Hiking, Cave, Stone, Nature',
#   53,
#   41],
#  ['https://cdn.pixabay.com/photo/2022/04/04/13/06/young-geese-7111224__480.jpg',
#   'taken on March 29, 2022',
#   21,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/09/16/45/flowers-7121849__340.jpg',
#   'Flowers, Bee, Pollen, Pollination',
#   5,
#   1],
#  ['https://cdn.pixabay.com/photo/2021/09/28/14/21/clocks-6664622__340.jpg',
#   'Clocks, Alarm Clocks, Time',
#   91,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/05/29/18/59/petra-6294051__340.jpg',
#   'Petra, Ad Deir, World Heritage',
#   305,
#   158],
#  ['https://cdn.pixabay.com/photo/2022/04/04/10/57/australian-wood-ducks-7110894__340.jpg',
#   'Australian Wood Ducks, Ducks, Birds',
#   38,
#   29],
#  ['https://cdn.pixabay.com/photo/2022/04/01/19/22/daffodils-7105507__340.jpg',
#   'Daffodils, Easter Eggs, Easter, Flowers',
#   45,
#   32],
#  ['https://cdn.pixabay.com/photo/2022/03/29/13/16/great-tit-7099470__340.jpg',
#   'Great Tit, Bird, Perched, Tit, Animal',
#   57,
#   43],
#  ['https://cdn.pixabay.com/photo/2022/04/08/14/27/bird-7119597__340.jpg',
#   'Bird, Duckling, Ornithology, Species',
#   10,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/04/08/10/28/bird-7119229__340.jpg',
#   'Bird, Pigeon, Ornithology, Species',
#   8,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/01/18/14/tulip-7041814__340.jpg',
#   'Tulip, Flower, Purple Flower, Dew',
#   89,
#   109],
#  ['https://cdn.pixabay.com/photo/2022/04/08/22/55/bird-7120475__340.jpg',
#   'Bird, True Sparrow, Ornithology, Species',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2016/03/04/19/36/beach-1236581__340.jpg',
#   'Beach, Sea, Ocean, Tropical',
#   2481,
#   465],
#  ['https://cdn.pixabay.com/photo/2020/02/16/20/29/nyc-4854718__340.jpg',
#   'Nyc, New York City, America, Usa, City',
#   248,
#   58],
#  ['https://cdn.pixabay.com/photo/2022/04/02/12/38/dandelion-7106936__340.jpg',
#   'Dandelion, Yellow Flower, Wildflower',
#   24,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/06/14/27/chrysanthemums-7115662__340.jpg',
#   'Chrysanthemums, Flowers, Yellow Flowers',
#   11,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/04/05/18/35/easter-7114212__340.jpg',
#   'Easter, Easter Eggs, Easter Nest',
#   22,
#   16],
#  ['https://cdn.pixabay.com/photo/2022/04/05/21/19/dog-7114449__340.jpg',
#   'Dog, Eurasier, Canine, Breed, Pet',
#   22,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/04/12/00/29/animal-7126909__340.jpg',
#   'Animal, Cat, Chartreux, Breed, Feline',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/06/11/30/girl-7115394__340.jpg',
#   'Girl, Smile, Camera, Photographer',
#   3,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/09/28/05/05/bird-6663217__340.jpg',
#   'Bird, Beak, Down, Feathers, Ornithology',
#   135,
#   83],
#  ['https://cdn.pixabay.com/photo/2022/04/08/23/47/flower-7120513__340.jpg',
#   'Flower, Zinnia Elegan, Flora, Nature',
#   6,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/11/15/33/bird-7126057__340.jpg',
#   'Bird, Goose, Egyptian Goose, Meadow',
#   5,
#   3],
#  ['https://cdn.pixabay.com/photo/2021/09/17/15/17/fruit-6633086__340.jpg',
#   'Fruit, Grapes, Organic, Healthy, Sweet',
#   74,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/12/08/32/diva-7127549__340.jpg',
#   'Diva, Drag, Pride, Queen, Beauty',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/11/15/48/ship-7126083__340.jpg',
#   'Ship, Sail, Sea, Training Ship, Ocean',
#   4,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/09/22/19/buildings-7122332__340.jpg',
#   'Buildings, City, Prague, Roofs, Towers',
#   4,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/09/15/26/spring-7121653__340.jpg',
#   'Spring, Drove, Nature, Germinate, Growth',
#   7,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/03/17/48/blackthorn-7109568__340.jpg',
#   'Blackthorn, Blossoms, Bud, Spring, Shrub',
#   27,
#   26],
#  ['https://cdn.pixabay.com/photo/2021/12/19/10/26/star-6880592__340.jpg',
#   'Star, Moon, Wise Men, Three Kings',
#   122,
#   86],
#  ['https://cdn.pixabay.com/photo/2021/08/02/10/45/cityscape-6516367__340.jpg',
#   'Cityscape, Travel, Tourism, Europe',
#   58,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/04/03/13/25/flowers-7108960__340.jpg',
#   'Flowers, Crown Imperial, Bloom, Blossom',
#   34,
#   31],
#  ['https://cdn.pixabay.com/photo/2022/03/27/15/37/cherry-blossoms-7095452__480.jpg',
#   'Cherry Blossoms, Pink Flowers',
#   48,
#   38],
#  ['https://cdn.pixabay.com/photo/2022/03/26/09/39/sheet-music-7092610__340.jpg',
#   'Sheet Music, Music, Tulips, Flower, Song',
#   25,
#   18],
#  ['https://cdn.pixabay.com/photo/2022/04/06/07/50/bird-7115038__340.jpg',
#   'Bird, Ornithology, Species, Fauna, Avian',
#   15,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/03/26/02/12/ss-speke-shipwreck-7092132__340.jpg',
#   'The SS Speke was a three masted steel ship built in Wales, 1891. In 1906 she was en route from Peru to Geelong, Australia, to collect a return cargo of wheat when she collided with the reef. This is the remains of her bow or &quot;nose&quot;.',
#   70,
#   72],
#  ['https://cdn.pixabay.com/photo/2022/03/17/15/47/flower-7074914__340.jpg',
#   'Flower, Rose, Rose Flower, Cereal',
#   60,
#   70],
#  ['https://cdn.pixabay.com/photo/2022/04/03/14/27/throttle-7109099__340.jpg',
#   'Throttle, Bird, Ornithology, Species',
#   27,
#   17],
#  ['https://cdn.pixabay.com/photo/2022/04/06/15/33/chihuahua-7115748__340.jpg',
#   'Chihuahua, Long-Haired Chihuahua, Dog',
#   25,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/03/23/16/55/sky-7087541__340.jpg',
#   'Sky, Clouds, Cumulus, Airspace, Dusk',
#   50,
#   41],
#  ['https://cdn.pixabay.com/photo/2017/02/16/19/47/bokeh-2072271__340.jpg',
#   'Bokeh, Pink, Light, Lights, Colors',
#   1133,
#   243],
#  ['https://cdn.pixabay.com/photo/2022/04/07/12/54/fruit-7117438__340.jpg',
#   'Fruit, Lemons, Heart, Food, Kitchen',
#   22,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/03/29/11/53/lungwort-7099288__340.jpg',
#   'Aufgenommen am 11.3.2022',
#   49,
#   42],
#  ['https://cdn.pixabay.com/photo/2022/01/22/16/26/lake-6957802__340.jpg',
#   'Lake, Lighthouse, Pier, Outdoors',
#   56,
#   14],
#  ['https://cdn.pixabay.com/photo/2021/07/16/18/28/czech-republic-6471576__340.jpg',
#   'Czech Republic, City, Architecture',
#   80,
#   18],
#  ['https://cdn.pixabay.com/photo/2013/11/28/10/36/road-220058__340.jpg',
#   'Road, Pavement, Landscape, Roadway',
#   2872,
#   616],
#  ['https://cdn.pixabay.com/photo/2022/04/01/07/41/goose-7104256__340.jpg',
#   'Goose, Waterfowl, Countryside, Rural',
#   42,
#   33],
#  ['https://cdn.pixabay.com/photo/2021/08/14/01/58/museum-6544420__340.jpg',
#   'Museum, Pyramid, Facade, Illuminated',
#   62,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/04/12/05/25/flowers-7127213__480.jpg',
#   'Flowers, Tulips, Spring, Flora, Garden',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/10/19/34/flower-7124156__340.jpg',
#   'Flower, Dust Trap, Stamen, Macro, Bloom',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/11/13/18/02/lake-6791971__340.jpg',
#   'Lake, Wetland, Mountains, Landscape',
#   45,
#   13],
#  ['https://cdn.pixabay.com/photo/2018/01/24/18/05/background-3104413__340.jpg',
#   'Background, Panorama, Sunset, Dawn, Dusk',
#   1562,
#   335],
#  ['https://cdn.pixabay.com/photo/2021/11/08/20/15/elephant-6780085__340.jpg',
#   'Elephant, Skin, Texture, Pachyderm',
#   46,
#   9],
#  ['https://cdn.pixabay.com/photo/2022/04/09/20/52/dresden-7122254__340.jpg',
#   'Dresden, Morning, Dawn, Landscape, Birds',
#   6,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/08/07/18/36/city-6529108__340.jpg',
#   'City, Architecture, Buildings',
#   78,
#   21],
#  ['https://cdn.pixabay.com/photo/2021/10/27/08/43/forest-6746433__340.jpg',
#   'Forest, Foliage, Nature, Shrub, Flora',
#   59,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/04/11/02/50/gift-box-7124574__340.jpg',
#   'Gift Box, Gift, Box, Ribbon, Package',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/06/15/29/ranunculus-7115737__340.jpg',
#   'Ranunculus, Flower, Blossom, Bloom',
#   26,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/09/18/22/cat-7122038__340.jpg',
#   'Cat, Animal, Pet, Kitten, Domestic',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/03/30/09/14/norway-maple-7100807__340.jpg',
#   'Aufgenommen am 25.3.2022',
#   47,
#   28],
#  ['https://cdn.pixabay.com/photo/2022/04/10/17/55/birds-7123909__340.jpg',
#   'Birds, Sea, Coast, Ships, Port, Travel',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/10/18/16/man-7123964__340.jpg',
#   'Man, Kayak, Rowing, Boat, Water, Lake',
#   10,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/04/10/09/55/bird-7123035__340.jpg',
#   'Bird, Branch, Black, Woods, River',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/08/29/15/43/torrent-6583626__340.jpg',
#   'Torrent, River, Forest, Water',
#   109,
#   58],
#  ['https://cdn.pixabay.com/photo/2021/02/02/15/23/rose-5974372__480.jpg',
#   'Rose, Red, Smoke, Fog, Red Rose, Flower',
#   370,
#   51],
#  ['https://cdn.pixabay.com/photo/2019/11/10/11/13/couple-4615557__340.jpg',
#   'Couple, Wedding, Marriage, Bridal',
#   480,
#   101],
#  ['https://cdn.pixabay.com/photo/2022/03/08/16/52/easter-eggs-7056166__340.jpg',
#   'Easter Eggs, Design, Decoration',
#   62,
#   77],
#  ['https://cdn.pixabay.com/photo/2022/04/02/02/16/fox-7106138__340.jpg',
#   'Fox, Planet, Fantasy, Animal, Nature',
#   10,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/31/12/07/bulb-7102867__340.jpg',
#   'Bulb, Butterfly, Light, Fire',
#   15,
#   16],
#  ['https://cdn.pixabay.com/photo/2021/10/11/12/49/boats-6700576__340.jpg',
#   'Boats, Lake, Travel, Outdoors, Dusk',
#   52,
#   14],
# ...
#   'Dandelion, Flower, Plant, Yellow Flower',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/02/07/35/scrap-7106473__340.jpg',
#   'Scrap, Rubble, Disposal, Iron, Metal',
#   18,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/04/09/10/08/seagull-7121183__340.jpg',
#   'Seagull, Bird, Animal, Rocks, Sea, Beach',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/03/11/15/58/enduro-7062560__340.jpg',
#   'Enduro, Motorbike, Lightning, Sky, Storm',
#   8,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/04/05/13/16/yellowstone-7113546__480.jpg',
#   'Yellowstone, Steam, Caldera, Nature',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/05/17/06/50/erotic-6259923__340.jpg',
#   'Erotic, Sexy, Women, Lesbian, Kiss',
#   58,
#   0],
#  ['https://cdn.pixabay.com/photo/2016/11/29/09/32/concept-1868728__340.jpg',
#   'Concept, Man, Papers, Person, Plan',
#   679,
#   108],
#  ['https://cdn.pixabay.com/photo/2022/01/16/00/45/crimson-rosella-6940993__340.jpg',
#   'Crimson Rosella, Rosella, Bird',
#   103,
#   116],
#  ['https://cdn.pixabay.com/photo/2022/04/10/01/53/bird-7122547__340.jpg',
#   'Bird, Chicken, Family, Farm, Nature',
#   3,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/09/18/33/lily-7122063__340.jpg',
#   'Lily, Flower, Plant, Lilac',
#   0,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/09/07/13/night-7120910__340.jpg',
#   'Night, Lights, Mood, Blue Houses',
#   0,
#   0],
#  ['https://cdn.pixabay.com/photo/2020/01/15/19/05/shibuyasky-4768679__340.jpg',
#   'Shibuyasky, Shibuya, Tokyo, Japan',
#   236,
#   29],
#  ['https://cdn.pixabay.com/photo/2017/07/15/15/50/fantasy-2506830__340.jpg',
#   'Fantasy, Surreal, Mask, Wall, Eye',
#   1264,
#   156],
#  ['https://cdn.pixabay.com/photo/2022/04/06/18/47/town-7116125__340.jpg',
#   'Town, Countryside, Travel, Tourism',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/11/16/11/cat-7126123__340.jpg',
#   'Cat, Animal, Pet, Kitten, Feline',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/11/01/40/river-7124516__340.jpg',
#   'River, Sunset, Mountain, Hill, Landscape',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/05/16/33/orchid-7114001__340.jpg',
#   'Orchid, Flower, Plant, Nature',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/06/19/46/bird-7116223__340.jpg',
#   'Bird, European Robin, Ornithology',
#   2,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/04/11/20/09/man-7126538__340.jpg',
#   'Man, Cuban Hat, Fashion, Old, Face',
#   0,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/04/16/05/cape-arkona-7111717__340.jpg',
#   'Cape Arkona, Beach, Baltic Sea, Germany',
#   4,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/11/15/14/37/ferris-wheel-6798369__480.jpg',
#   'Ferris Wheel, Wiener Riesenrad',
#   52,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/11/30/04/46/video-editing-6834406__340.jpg',
#   'Video Editing, Videographer, Vlogger',
#   15,
#   5],
#  ['https://cdn.pixabay.com/photo/2020/08/29/09/26/beach-5526592__340.jpg',
#   'Beach, Rocks, Mediterranean, Sea',
#   178,
#   53],
#  ['https://cdn.pixabay.com/photo/2022/04/01/13/10/starbird-7104789__340.jpg',
#   'Starbird, Bird, Common Starling',
#   10,
#   6],
#  ['https://cdn.pixabay.com/photo/2022/04/05/14/11/spring-7113708__340.jpg',
#   'Spring, Cherry Blossoms, Japan',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/03/29/15/06/spruce-7099558__340.jpg',
#   'Spruce, Tree, Needles, Branch, Forest',
#   17,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/07/21/37/crocuses-7118295__340.jpg',
#   'Crocuses, Purple Flowers, Spring, Meadow',
#   2,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/03/25/15/54/plum-blossoms-7091313__340.jpg',
#   'Plum Blossoms, Bee, Pollination, Macro',
#   10,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/02/26/08/12/erika-7035386__340.jpg',
#   'Aufgenommen am 23.2.2022',
#   43,
#   33],
#  ['https://cdn.pixabay.com/photo/2022/03/19/21/11/flower-7079547__340.jpg',
#   'Flower, Crocus, Spring, Bloom, Nature',
#   18,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/04/11/17/55/iphones-7126319__340.jpg',
#   'Iphones, Smartphones, Mobile Phones',
#   0,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/10/31/09/25/animal-6756751__340.jpg',
#   'Animal, Goat, Mammal, Livestock, Farm',
#   53,
#   20],
#  ['https://cdn.pixabay.com/photo/2019/06/12/21/10/ocean-4270251__340.jpg',
#   'Ocean, Beach, Water, Sand, Nature, Coast',
#   162,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/04/06/08/44/leaf-beetle-7115135__340.jpg',
#   'Leaf Beetle, Beetle, Insect, Bug',
#   3,
#   2],
#  ['https://cdn.pixabay.com/photo/2017/02/13/21/57/lake-2063957__340.jpg',
#   'Lake, Water, Wave, Mirroring, Background',
#   1473,
#   176],
#  ['https://cdn.pixabay.com/photo/2022/04/08/23/58/sky-7120529__340.jpg',
#   'Sky, Clouds, Sunset, Dusk, Outdoors',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/01/09/05/04/cottage-6925258__480.jpg',
#   'Cottage, Valley, Countryside, Landscape',
#   24,
#   7],
#  ['https://cdn.pixabay.com/photo/2021/12/01/19/53/business-6839039__340.jpg',
#   'Business, Meeting, Partnership',
#   11,
#   5],
#  ['https://cdn.pixabay.com/photo/2016/11/18/19/01/paris-1836415__340.jpg',
#   'Paris, France, Eiffel Tower, Night, City',
#   794,
#   94],
#  ['https://cdn.pixabay.com/photo/2020/06/05/19/02/chamber-5264172__340.jpg',
#   'Spieglein Spieglein an der Wand…',
#   203,
#   61],
#  ['https://cdn.pixabay.com/photo/2021/07/14/18/34/poppy-6466826__340.jpg',
#   'Poppy, White, Sown, Flowers, Poppy Field',
#   105,
#   36],
#  ['https://cdn.pixabay.com/photo/2022/04/06/20/56/lake-garda-7116371__340.jpg',
#   'Lake Garda, Italy, Town, Lake',
#   3,
#   1],
#  ['https://cdn.pixabay.com/photo/2020/09/01/06/10/lake-5534341__340.jpg',
#   'Lake, Cow, Highland Cattle, Animal',
#   328,
#   59],
#  ['https://cdn.pixabay.com/photo/2017/06/15/23/47/painting-2407262__340.jpg',
#   'Painting, Watercolor, Paint, Paper',
#   966,
#   175],
#  ['https://cdn.pixabay.com/photo/2022/04/01/17/42/tree-7105326__340.jpg',
#   'Tree, Magnolia, Spring, Nature, Flower',
#   4,
#   3],
#  ['https://cdn.pixabay.com/photo/2022/04/01/22/49/blackburnian-warbler-7105859__340.jpg',
#   'Blackburnian Warbler, Warbler, Bird',
#   4,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/03/24/09/09/pink-flower-7088699__340.jpg',
#   'Pink Flower, Rhododendron, Flower Bud',
#   23,
#   18],
#  ['https://cdn.pixabay.com/photo/2022/03/25/10/49/easter-7090760__340.jpg',
#   'Easter, Spring, Window, Nature',
#   16,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/03/19/13/51/easter-7078596__340.jpg',
#   'Easter, Easter Festival, Easter Bunny',
#   26,
#   22],
#  ['https://cdn.pixabay.com/photo/2017/02/04/12/25/man-2037255__340.jpg',
#   'Man, Board, Drawing, Muscles, Strong',
#   1263,
#   230],
#  ['https://cdn.pixabay.com/photo/2017/06/27/11/48/team-spirit-2447163__480.jpg',
#   'Team Spirit, Teamwork, Community',
#   831,
#   189],
#  ['https://cdn.pixabay.com/photo/2022/03/30/22/42/hyacinth-7101887__340.jpg',
#   'Hyacinth, Flower, Plant, Petals, Bloom',
#   6,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/08/12/55/forest-7119450__340.jpg',
#   'Forest, Path, Walking, Couple, Leisure',
#   5,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/28/05/14/liverworts-7096602__340.jpg',
#   'Liverworts, Flower, Plant, Spring',
#   8,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/07/29/14/48/new-york-6507350__340.jpg',
#   'New York, City, Road, Street, Monochrome',
#   28,
#   4],
#  ['https://cdn.pixabay.com/photo/2017/10/18/16/08/wolves-2864647__340.jpg',
#   'Wolves, Wolf Pack, Forest, Woods',
#   1076,
#   92],
#  ['https://cdn.pixabay.com/photo/2022/01/15/20/35/mushroom-6940686__340.jpg',
#   'Mushroom, Squirrel, Rodent, Animal',
#   30,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/01/13/51/sea-7104852__340.jpg',
#   'Sea, Ocean, Moon, Moonlight, Fantasy',
#   3,
#   1],
#  ['https://cdn.pixabay.com/photo/2021/01/27/13/47/cliff-5954980__340.jpg',
#   'Cliff, Coast, Beach, Island, Coastline',
#   159,
#   23],
#  ['https://cdn.pixabay.com/photo/2022/04/05/15/16/flowers-7113837__340.jpg',
#   'Flowers, Cosmos, Bloom, Blossom, Botany',
#   5,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/02/25/08/07/snail-7033736__340.jpg',
#   'Snail, Shell, Animal, Mollusc, Mucus',
#   41,
#   35],
#  ['https://cdn.pixabay.com/photo/2022/04/04/14/49/farm-7111493__340.jpg',
#   'Farm, Rice Field, Thailand, Nature',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2020/12/16/12/05/horse-5836459__340.jpg',
#   'Horse, Stallion, Equine, Equestrian',
#   283,
#   96],
#  ['https://cdn.pixabay.com/photo/2021/08/29/14/43/alley-6583471__340.jpg',
#   'Alley, Stairs, Buildings, City, Tourist',
#   56,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/02/02/23/11/frog-figurine-6989567__340.jpg',
#   'Frog Figurine, Travel, Figurine',
#   38,
#   9],
#  ['https://cdn.pixabay.com/photo/2022/04/03/08/37/death-valley-7108367__340.jpg',
#   'Death Valley, Salt Lake, Valley Of Death',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/03/11/42/flowers-7108730__480.jpg',
#   'Flowers, Crocuses, Botany, Seasonal',
#   6,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/04/12/09/21/milk-7127651__340.jpg',
#   'Milk, Splash, Drop, Ripples, Liquid',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/01/04/18/32/archway-6915701__340.jpg',
#   'Archway, Architecture, Portal, Light',
#   24,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/03/21/00/44/surreal-7082067__340.jpg',
#   'Surreal, Cyborg, Spider, Fantasy, Robot',
#   27,
#   37],
#  ['https://cdn.pixabay.com/photo/2021/06/27/19/50/sunset-6369825__340.jpg',
#   'Sunset, Mountains, Forest, Fog, Nature',
#   69,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/02/09/25/plum-blossoms-7106582__340.jpg',
#   'Plum Blossoms, Plum Flowers, Plum Tree',
#   7,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/28/07/34/flowers-7096839__340.jpg',
#   'Flowers, Blossom, Bloom, Nature, Flora',
#   17,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/01/23/03/18/farming-6959638__340.jpg',
#   'Farming, Colombian Coffee, Colombia',
#   19,
#   2],
#  ['https://cdn.pixabay.com/photo/2016/09/08/13/58/desert-1654439__340.jpg',
#   'Desert, Sand, Dunes, Landscape',
#   959,
#   130],
#  ['https://cdn.pixabay.com/photo/2022/03/25/16/11/lake-7091363__340.jpg',
#   'Lake, Nature, Trees, Reflection, Water',
#   14,
#   10],
#  ['https://cdn.pixabay.com/photo/2021/12/11/11/48/nature-6862612__340.jpg',
#   'Faro de Fisterra',
#   33,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/07/20/03/duck-7118213__340.jpg',
#   'Duck, White Duck, Bird, Cuba, Lake',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/07/15/16/19/sea-6468912__340.jpg',
#   'Sea, Path, Fog, Concrete, Coast, Ocean',
#   51,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/02/05/25/crocus-7106338__340.jpg',
#   'Crocus, Flower, Yellow Crocus',
#   3,
#   1],
#  ['https://cdn.pixabay.com/photo/2016/10/22/20/34/wines-1761613__340.jpg',
#   'Wines, Glasses, Wine Glasses, Stemware',
#   1247,
#   178],
#  ['https://cdn.pixabay.com/photo/2022/04/06/11/27/mountains-7115391__480.jpg',
#   'Mountains, Sunset, Road, Highway, Nature',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/09/22/33/daffodil-7122360__340.jpg',
#   'Daffodil, Flower, White Flower, Garden',
#   4,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/04/05/15/26/cat-7113867__340.jpg',
#   'Cat, Pet, Animal, Field, Flowers',
#   6,
#   4],
#  ['https://cdn.pixabay.com/photo/2022/03/30/14/00/texas-bluebell-7101234__340.jpg',
#   'Texas Bluebell, Flowers, Plant',
#   11,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/04/05/13/15/bear-7113542__340.jpg',
#   'Bear, Cub, Yearling, River, Montana',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2018/01/30/22/48/rainforest-3119822__340.jpg',
#   'Rainforest, Jungle, Stream, Trees',
#   693,
#   126],
#  ['https://cdn.pixabay.com/photo/2022/03/23/13/58/siberian-squill-7087293__340.jpg',
#   'Siberian Squill, Flowers, Blue Star',
#   24,
#   19],
#  ['https://cdn.pixabay.com/photo/2020/06/30/11/11/landscape-5356009__340.jpg',
#   'Landscape, Fantasy, Night, Darling, Star',
#   492,
#   138],
#  ['https://cdn.pixabay.com/photo/2021/06/30/13/14/ocean-6376743__340.jpg',
#   'Ocean, Sea, Seascape, Beach, Water',
#   97,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/03/30/19/09/north-american-river-otters-7101722__340.jpg',
#   'North American River Otters, Animals',
#   5,
#   1],
#  ['https://cdn.pixabay.com/photo/2018/05/04/15/23/poppies-3374193__340.jpg',
#   'Poppies, Flowers, Field, Poppy Field',
#   577,
#   65],
#  ['https://cdn.pixabay.com/photo/2022/03/26/13/02/flower-7092891__340.jpg',
#   'Flower, Hibiscus, Flora, Nature, Botany',
#   12,
#   18],
#  ['https://cdn.pixabay.com/photo/2022/03/23/19/17/daffodil-7087740__340.jpg',
#   'Daffodil, Yellow Flower, Meadow, Spring',
#   17,
#   13],
#  ['https://cdn.pixabay.com/photo/2021/07/04/17/29/caterpillar-6387049__340.jpg',
#   'Caterpillar, Dovetail, Insect, Nature',
#   136,
#   68],
#  ['https://cdn.pixabay.com/photo/2022/03/21/19/17/bird-7083795__340.jpg',
#   'Bird, Summer Tanager, Ornithology',
#   14,
#   10],
#  ['https://cdn.pixabay.com/photo/2021/10/06/15/05/bedroom-6686059__480.jpg',
#   'Bedroom, Furniture, Interior Design',
#   10,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/06/03/03/32/birds-6305827__340.jpg',
#   'Birds, Fledgling, Feeding',
#   136,
#   42],
#  ['https://cdn.pixabay.com/photo/2020/11/25/03/04/russian-blue-cat-5774414__340.jpg',
#   'Russian Blue Cat, Cat, Pet, Gray Cat',
#   89,
#   17],
#  ['https://cdn.pixabay.com/photo/2021/04/30/03/14/road-6217805__340.jpg',
#   'Road, Trees, Cherry Blossoms, Spring',
#   91,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/05/11/47/words-7113398__340.jpg',
#   'Words, Letters, Wood, Playtime, Fun',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/06/09/34/traffic-7115188__340.jpg',
#   'Traffic, Road, Asphalt, Car, Volkswagen',
#   7,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/03/28/16/50/root-7097943__340.jpg',
#   'Root, Forest, Wilderness, Outdoors',
#   15,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/05/07/42/flowers-7112992__340.jpg',
#   'Flowers, Plum Blossom, Spring, Seasonal',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/01/11/17/liberec-7104563__340.jpg',
#   'Liberec, Czechia, City, Czech, Museum',
#   4,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02/26/08/07/castle-7035378__340.jpg',
#   'Burgfrieden',
#   42,
#   31],
#  ['https://cdn.pixabay.com/photo/2022/04/03/23/39/bird-7110038__340.jpg',
#   'Bird, Common Redpoll, Ornithology',
#   3,
#   2],
#  ['https://cdn.pixabay.com/photo/2020/12/30/14/26/lion-5873637__340.jpg',
#   'Lion, Cat, Feline, Carnivore, Predator',
#   153,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/07/09/19/12/brooklyn-bridge-6399829__340.jpg',
#   'None',
#   66,
#   27],
#  ['https://cdn.pixabay.com/photo/2022/04/04/20/05/zoo-7112308__340.jpg',
#   'Zoo, Meerkat, Wildlife, Animal, Nature',
#   4,
#   2],
#  ['https://cdn.pixabay.com/photo/2021/12/24/12/13/fantasy-6891021__340.jpg',
#   'Fantasy, Picturesque, Landscape',
#   33,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/04/05/12/41/chilli-7113479__480.jpg',
#   'Chilli, Pepper, Organic, Vegetable',
#   1,
#   0],
#  ['https://cdn.pixabay.com/photo/2017/12/17/19/08/bridge-3024773__340.jpg',
#   'Bridge, Path, Park, Wooden Bridge, Trail',
#   1333,
#   147],
#  ['https://cdn.pixabay.com/photo/2022/04/04/22/12/sailboat-7112452__340.jpg',
#   'Sailboat, Lake, Vessel, Boat, Travel',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/06/17/42/girl-7116005__340.jpg',
#   'Girl, Happy, Talking, Phone Call',
#   7,
#   1],
#  ['https://cdn.pixabay.com/photo/2022/02/03/10/23/mushrooms-6990153__340.jpg',
#   'Mushrooms, Plants, Toadstool, Mycology',
#   36,
#   29],
#  ['https://cdn.pixabay.com/photo/2022/04/06/11/27/flower-7115380__340.jpg',
#   'Flower, Rose, Bloom, Blossom, Botany',
#   2,
#   0],
#  ['https://cdn.pixabay.com/photo/2020/11/02/07/51/leaves-5705990__340.jpg',
#   'Leaves, Tree, Fall, Branch, Plant, Flora',
#   137,
#   41],
#  ['https://cdn.pixabay.com/photo/2022/04/06/17/16/pills-7115972__340.jpg',
#   'Pills, Medicines, Closeup, Pink',
#   3,
#   0],
#  ['https://cdn.pixabay.com/photo/2016/11/19/10/29/background-1838494__340.jpg',
#   'Background, Leather, Brown, Close Up',
#   607,
#   126],
#  ['https://cdn.pixabay.com/photo/2022/03/08/11/21/sloe-7055582__340.jpg',
#   'Aufgenommen am 5.3.2022',
#   45,
#   44],
#  ['https://cdn.pixabay.com/photo/2022/04/06/21/49/strawberry-7116430__340.jpg',
#   'Strawberry, Berry, Fruit, Juicy, Food',
#   0,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/04/04/07/32/botany-7110560__340.jpg',
#   'Botany, Flower, Blossom, Bloom, Blooming',
#   0,
#   0],
#  ...]

# %%
data = pd.DataFrame(data, columns = ['Link', 'Tags', 'Likes', 'Comments'])
data
# Out:
#                                                    Link  \
# 0     https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1     https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2     https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3     https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4     https://cdn.pixabay.com/photo/2022/04/09/18/06...
# ...                                                 ...
# 9099  https://cdn.pixabay.com/photo/2018/01/08/18/51...
# 9100  https://cdn.pixabay.com/photo/2021/09/22/01/42...
# 9101  https://cdn.pixabay.com/photo/2022/01/09/15/58...
# 9102  https://cdn.pixabay.com/photo/2021/08/10/11/59...
# 9103  https://cdn.pixabay.com/photo/2021/10/03/01/01...
#
#                                          Tags  Likes  Comments
# 0           Clouds, Sky, Atmosphere, Blue Sky    196        55
# 1              Bird, Ornithology, Hummingbird     76        20
# 2         Sea, Rainbow, Rainfall, Subtropical    282       106
# 3        Cherry Blossoms, Road, Japan, Sakura     42        11
# 4              Cape Marguerite, Flower, Plant     39        15
# ...                                       ...    ...       ...
# 9099   Pear, Fruit, Food, Background, Healthy     75        11
# 9100   Ants, Insects, Plants, Flowers, Animal     13         8
# 9101            Flower, Flora, Garden, Nature      0         0
# 9102  Kara Dag Mountain, Resort Village, Town      6         2
# 9103        Island, Lake, Fog, Forest, Nature     22        17
#
# [9104 rows x 4 columns]

# %%
data.to_csv('ImageScraping.csv', index = False)

# %% [markdown]
# #### Downloading the Images and Storing in a Folder

# %%
import requests

# %%
loc =[]

for i in tqdm(data['Link']):
    res = requests.get(i)

    #print(str(i)+"\t"+str(i.split('/')))
    #break
    
    #os.mkdir('Collection')
    
    # https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg	
    # ['https:', '', 'cdn.pixabay.com', 'photo', '2022', '03', '06', '05', '30', 'clouds-7050884__480.jpg']
    # clouds-7050884__480.jpg ---> To get
    
    fd = open('Collection/'+i.split('/')[-1],'wb')
    fd.write(res.content)
    fd.close()
    
    loc.append('Collection/'+i.split('/')[-1])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9104/9104 [36:51<00:00,  4.12it/s]

# %%
data['Location'] = loc

# %%
data.to_csv('ImageScraping_2.csv', index =False)

# %%
data
# Out:
#                                                    Link  \
# 0     https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1     https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2     https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3     https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4     https://cdn.pixabay.com/photo/2022/04/09/18/06...
# ...                                                 ...
# 9099  https://cdn.pixabay.com/photo/2018/01/08/18/51...
# 9100  https://cdn.pixabay.com/photo/2021/09/22/01/42...
# 9101  https://cdn.pixabay.com/photo/2022/01/09/15/58...
# 9102  https://cdn.pixabay.com/photo/2021/08/10/11/59...
# 9103  https://cdn.pixabay.com/photo/2021/10/03/01/01...
#
#                                          Tags  Likes  Comments  \
# 0           Clouds, Sky, Atmosphere, Blue Sky    196        55
# 1              Bird, Ornithology, Hummingbird     76        20
# 2         Sea, Rainbow, Rainfall, Subtropical    282       106
# 3        Cherry Blossoms, Road, Japan, Sakura     42        11
# 4              Cape Marguerite, Flower, Plant     39        15
# ...                                       ...    ...       ...
# 9099   Pear, Fruit, Food, Background, Healthy     75        11
# 9100   Ants, Insects, Plants, Flowers, Animal     13         8
# 9101            Flower, Flora, Garden, Nature      0         0
# 9102  Kara Dag Mountain, Resort Village, Town      6         2
# 9103        Island, Lake, Fog, Forest, Nature     22        17
#
#                                            Location
# 0                Collection/clouds-7050884__480.jpg
# 1                  Collection/bird-7117346__340.jpg
# 2                   Collection/sea-7039471__340.jpg
# 3       Collection/cherry-blossoms-7110279__340.jpg
# 4       Collection/cape-marguerite-7121992__340.jpg
# ...                                             ...
# 9099               Collection/pear-3070020__340.png
# 9100               Collection/ants-6645412__480.jpg
# 9101             Collection/flower-6926320__340.jpg
# 9102  Collection/kara-dag-mountain-6535841__340.jpg
# 9103             Collection/island-6676628__340.jpg
#
# [9093 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# Link        0
# Tags        0
# Likes       0
# Comments    0
# Location    0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data = pd.read_csv('ImageScraping_2.csv')

# %%
tag = set()
for i in data['Tags']:
    for j in i.split(','):
        tag.add(j)

# %%
tag.remove('')

# %%
tag
# Out:
# {' Solidarity',
#  'Whiteboard',
#  'Washington Dc',
#  ' Tunnel',
#  ' Solitude',
#  ' Dissolve',
#  ' Eastern Grey Kangaroo',
#  'Lavenders',
#  ' Anniversary',
#  ' Agapanthus',
#  'Winter',
#  ' Wolves',
#  ' Work From Home',
#  ' Surgeon',
#  ' Schaumomelette',
#  ' Transparent',
#  'taken on March 29',
#  ' Collar',
#  ' Heart Macaron',
#  ' Sheep',
#  ' Schoolgirl',
#  ' Bubble',
#  ' Altai Mountains',
#  'Madonna Lily',
#  ' River',
#  ' Cutting Board',
#  'Kingfisher',
#  ' Arches',
#  ' Shellfish',
#  ' Skin',
#  'Fennel',
#  'Penguins',
#  ' Lighting Mood',
#  ' Provence',
#  ' Two Lion',
#  ' Violet',
#  'Mountaineer',
#  'Hobbit',
#  ' Chipped',
#  ' Cyprus',
#  ' Uhu',
#  'Castle',
#  'Rabbit',
#  'Das versteckte Haus...',
#  ' Lemurs',
#  ' Beautiful',
#  ' Bright',
#  'Makeup',
#  ' Persian',
#  'Wardrobe',
#  ' Training Ship',
#  ' Dolphin Bananas',
#  'Egret',
#  ' View',
#  ' Mythical Creatures',
#  'Buddhist Temple',
#  'Hazelnut',
#  'Santa Claus',
#  ' Wood Chips',
#  'Windmühlen am Mandraki-Hafen auf Rhodos',
#  'Stealth',
#  'Rose Hips',
#  'Sugarcane',
#  ' Stree',
#  ' Archidaily',
#  ' Medium',
#  ' Scissors',
#  'Reed',
#  ' Energy',
#  ' Kamchatka',
#  ' Biontech Comirnaty',
#  ' Videographer',
#  'Flamingo Flower',
#  ' Stress',
#  ' Fresh Air',
#  ' Swirls',
#  ' Linen',
#  'Christmas Motif',
#  'Bird Skull',
#  ' Land',
#  ' Tansy',
#  ' Clothespins',
#  ' Object',
#  ' Restaurants',
#  'Bedroom',
#  ' Milky Way',
#  'Tv',
#  'The Night',
#  ' Traces',
#  ' Accident',
#  ' Swabian Jura',
#  ' Inject',
#  ' Quartz',
#  ' Outdoor Sports',
#  ' Backpacking',
#  'Christmas Background',
#  ' Pigment',
#  ' Safari',
#  ' Landing',
#  ' Call',
#  'Tit',
#  'Air Force',
#  ' Blue Jeans',
#  'Pasture Fence',
#  ' Cartoon',
#  'Treasure Chest',
#  ' Narcissus',
#  'Stairs',
#  ' Milford Sound',
#  ' Wheelchair',
#  'Zen',
#  ' Frangipanis',
#  ' Distillery',
#  'Snow Leopard',
#  ' Seasonal',
#  'Rails',
#  ' Airshow',
#  ' Mock Oranges Blossoms',
#  ' European Bee Eater',
#  ' Pasture',
#  'Mallow',
#  ' Seashells',
#  'Christmas Cookie',
#  ' Keep',
#  ' Shore',
#  ' Turntable',
#  'Duck Meet',
#  ' A Smile',
#  ' Coffee Cup',
#  ' Wanaka',
#  ' Cavern',
#  ' Chinese',
#  ' Orange',
#  ' Butterfly Orchid',
#  ' Busy',
#  ' Korean',
#  'Port',
#  'Conclusion Of Contract',
#  ' Daily Newspaper',
#  'Grain',
#  'Daisies',
#  ' Yellow Dahlia',
#  ' Models',
#  ' Effect',
#  'Soil',
#  'Destination',
#  ' Christmas Motif',
#  ' Cat Face',
#  'Chamois',
#  ' Folding Chairs',
#  ' Mankind',
#  'Rape Blossom',
#  ' Apple Cider',
#  ' Pink-Purple',
#  ' Cozy',
#  ' Biology',
#  ' Quang Ninh',
#  ' Bulbul',
#  ' Cat Mother',
#  ' Fun',
#  ' Wallpaper',
#  ' Garlic',
#  'Suitcase',
#  'Seascape',
#  ' Pub',
#  ' Sourdough',
#  ' Bethlehem',
#  'Gnomes',
#  'Fashion',
#  ' Heavy',
#  'Arctic Wolf',
#  'Bees',
#  ' Willow Catkin',
#  ' Algae',
#  ' Moonlight',
#  ' Wilderness',
#  'Hellebore',
#  'Versailles',
#  ' Bokeh',
#  ' Hues',
#  'Bathroom',
#  ' Chinese Style',
#  ' Stinking Hellebore',
#  ' Texas',
#  'Outlook',
#  ' African',
#  'Sofa',
#  ' Blossom',
#  ' Music Sheet',
#  'Roofers',
#  'Mangrove',
#  'Rv',
#  'Teddy Bear',
#  'Cryptocurrency',
#  'Candle',
#  ' Law Of Nature',
#  ' Earth',
#  'Pyramids',
#  ' New',
#  ' Bow',
#  'Wellness',
#  ' Mallorca',
#  ' Mantodea',
#  ' Carpet',
#  ' Belluno',
#  'Frangi Pani',
#  ' Aquatic Animal',
#  ' Huner',
#  ' Digital Vaccination Record',
#  ' Sauteed',
#  'Papillon',
#  'Azaleas',
#  ' Pirate Ship',
#  'Marshmallows',
#  ' Diagonal',
#  'Goldcrest',
#  ' Butterfly',
#  ' Electric Scooter',
#  ' Blood Church',
#  'Macaw',
#  ' Growth',
#  ' Travel Map',
#  ' Refueling',
#  'Cocktail',
#  ' Olive',
#  ' Jewelry',
#  ' Corporate',
#  ' Countries',
#  ' To Organize',
#  ' Cairo',
#  'Pate',
#  ' Cloud Shape',
#  ' Healthy Eating',
#  ' Boy',
#  ' Gladiolus',
#  'Spring Flowers',
#  ' Flamingo',
#  ' Nutrition',
#  ' Mirroring',
#  ' Raspberries',
#  ' Analysis',
#  ' Contact',
#  'Diamond',
#  'Fire Bowl',
#  'Canals',
#  'Books',
#  ' Little Boy',
#  ' Guitarist',
#  'Bird',
#  'Studying',
#  'Singing Bowl',
#  'Television',
#  ' Larch Tree',
#  'Buddha',
#  'Rajasthan',
#  ' Chicken',
#  ' Kingfisher',
#  ' Calm Down',
#  ' Then',
#  ' Candles',
#  'Bulgarian forest in winter',
#  ' Catholic',
#  ' Goose Head',
#  ' Mythology',
#  ' Fermentation',
#  ' Ornaments',
#  ' Town Square',
#  'Couch',
#  ' Alpine Pastures',
#  ' Domestic Cat',
#  'Black-And-White',
#  'France',
#  'Hanoi',
#  ' Porsche',
#  ' Puppy Kitten',
#  'Narcissus',
#  ' Tourism',
#  ' Fiery',
#  ' Graveyard',
#  'Badlands National Park',
#  ' Score',
#  'Company',
#  ' Ochna Serrulata',
#  ' Japanese-Style Garden',
#  'Software: Gimp 2.10.24',
#  'Summer',
#  'Statue Of Liberty',
#  'Ants',
#  'Lego',
#  ' Pedestrian Zone',
#  ' Petals',
#  'Almonds',
#  ' Castel San Pietro',
#  'Canadian Goose',
#  ' Start-Up',
#  ' Agrigento',
#  ' Eagle',
#  ' starfish',
#  ' unweit von Chemnitz an der B174 Richtung Marienberg.',
#  ' Ear',
#  ' Mountain Ranges',
#  'Fantasmagòrica vista de los Reyes Magos de Oriente .',
#  'Railroad',
#  ' City',
#  'Balloons',
#  ' Egrets',
#  'Eth',
#  'Inspired by: https://pixabay.com/photos/animal-zebra-mammal-mountain-zebra-6997104/',
#  ' Coffee Mug',
#  ' Savings',
#  'Cardinals',
#  ' Snowfield',
#  ' Old',
#  ' Voorjaarsbloem',
#  'Computer',
#  ' Game Of Thrones',
#  'Antique Car',
#  ' Vaccine',
#  ' Baby Mouse',
#  ' Sexuality',
#  ' Irresponsible',
#  ' Voice',
#  'Gourds',
#  'Pineapple',
#  ' Ruby',
#  'Head Massage',
#  ' Van',
#  ' Basil',
#  'Han River',
#  'Equestrian',
#  ' Paint Brush',
#  ' beautiful vintage',
#  ' Pet',
#  'Children',
#  ' Nose',
#  ' Hongyadong',
#  ' Samurai',
#  ' Bornholmmargerite',
#  ' Desktop',
#  ' Firefighter',
#  ' Fillet',
#  ' Dovetail',
#  ' Mountain Panorama',
#  ' Vanessa Atalanta',
#  ' Adventure',
#  'Happy',
#  ' Maharashtra',
#  ' Hospital',
#  ' Plant Protection Drone',
#  ' Projects',
#  ' Fragrant',
#  ' Sweet Pastries',
#  'Monster',
#  ' Christmas Ornament',
#  ' Bruges',
#  'Bell Tower',
#  ' Fir Trees',
#  ' Worried',
#  'Ornament',
#  'Mint',
#  ' White Space',
#  'Guitar',
#  ' Handshake',
#  ' Biscuits',
#  ' Bookshelf',
#  ' Alleyway',
#  ' Japanese Garden',
#  'Combing',
#  ' Galveston',
#  ' Stone Tower',
#  'Audi',
#  ' Handwritten',
#  'Camels',
#  'Write',
#  'Prayer',
#  'Pieris Rapae',
#  ' Lightning Storm',
#  'Al-Aqsa',
#  'bab',
#  ' Saltmarsh Sparrow',
#  ' White Rose',
#  ' Common Onion',
#  ' Teeth',
#  ' Running Shoes',
#  ' Roll',
#  'Santiago Calatrava',
#  ' Masts',
#  ' Sketch Pad',
#  ' Area',
#  ' Cyclamen',
#  ' Bird Feeder',
#  ' Thessaloniki',
#  'Skyscraper',
#  'Imapala',
#  ' Tortoise',
#  ' Lisbon',
#  ' Thimble',
#  ' Moutains',
#  ' Asleep',
#  'Bulb',
#  ' Shack',
#  ' Land Scape',
#  ' Aerial',
#  ' Torii Tunnel',
#  'Computer Games',
#  'Digital Background',
#  ' Fairy Tales',
#  'Cold',
#  ' Model Car',
#  'Campfire',
#  ' Virtual',
#  ' Lhasa Apso',
#  ' Solar System',
#  ' Winter Solstice',
#  'entstanden auf meiner Alpenüberquerung Oberstdorf - Meran im Pitztal',
#  ' Utensils',
#  ' Cucumber',
#  'Hayfield',
#  ' Birch',
#  'Silberreiher',
#  'Scooter',
#  ' Kremlin',
#  'Tanks',
#  ' Teton Mountains',
#  ' Africa',
#  ' Hummus',
#  'Cami',
#  ' Dog',
#  ' Studio',
#  'Medinilla',
#  'Rasender Roland',
#  'Prince',
#  ' Shield',
#  ' Memo',
#  'Workspace',
#  'Pear Blossom',
#  ' Fish Tank',
#  'Okanagan Rail Trail',
#  'Summer Tanager',
#  'Iguana',
#  ' Dumper',
#  'Red Roses',
#  ' Door Husband',
#  'Red Hibiscus',
#  'Stay Home',
#  ' Squash',
#  'Snowflake',
#  ' Little Waterfall',
#  'Tower',
#  ' Mojito',
#  ' Fitzroy National Park',
#  ' Transportation',
#  ' Pohang',
#  'Sand Dune',
#  'Advent',
#  'green trees on brown rock formation on lake during daytime',
#  ' Wheat Field',
#  ' Wing',
#  'Sprouts',
#  'Yellow Macaw',
#  'Liver Flower',
#  ' Fancy',
#  ' Cats',
#  ' Burger',
#  ' Bird Feather',
#  ' Skincare',
#  'Tower Bridge',
#  ' Candlestick',
#  'Cyber Security',
#  ' Bmw',
#  'Multiple replications of bananas',
#  ' Upholstery',
#  ' Standing',
#  'Construction Site near Herman National Park',
#  ' Sharp',
#  ' Stock',
#  ' Worker',
#  ' Structure',
#  ' Toilets',
#  ' Semi-Trailer',
#  ' Vw',
#  ' Bone',
#  'Banknotes',
#  ' Telegram',
#  ' Diagram',
#  ' Lebanon',
#  ' Ukrainian Flag',
#  ' Yucatan Woodpecker',
#  ' Sandstone',
#  ' Sunbeams',
#  ' Colony',
#  'Shopping',
#  ' Pie',
#  ' Ore Mining',
#  ' Water Drop',
#  ' New Zealand',
#  ' Looking',
#  ' Wiener Riesenrad',
#  ' Desktop Wallpaper',
#  'Makeup Brush',
#  'Mushroo',
#  ' Picturesque',
#  'Your body is important',
#  ' Ribeye',
#  'Maine Coon',
#  ' Night Sky',
#  ' Boardwalk',
#  ' Avenue',
#  ' Cheeseburger',
#  'Bull Frog',
#  'Charles Bridge',
#  ' Pony',
#  ' Butterflies',
#  'Sand Dunes',
#  'Mandarin Ducks',
#  ' Yellow',
#  ' Waterfowl',
#  'grayscale photography of man wearing knit cap',
#  ' Building',
#  ' Traffic Jam',
#  'Fir Branches',
#  'Budgie',
#  'Peace',
#  'Newborn',
#  ' Children',
#  ' Few',
#  'Border Collie',
#  ' Golden Eagle',
#  'Attraction',
#  ' Politician',
#  'It’s a matter of heart',
#  ' Ground Fog',
#  ' Traveling',
#  '4 Weihnachtskerzen',
#  'Hunger',
#  'Portugal',
#  ' Starling',
#  'Painted Guitar',
#  'Florence',
#  'Conversation Hearts',
#  'Girls',
#  'Easter',
#  'Seifenblasen auf Flüssigkeit farbig',
#  'Space',
#  ' Google',
#  ' Natural Satellite',
#  'Covid-19',
#  ' Egyptian Goslings',
#  'Maple',
#  'A splash of colour in the grey',
#  ' Rose Blossom',
#  ' Green Iguana',
#  ' Freight',
#  ' Health',
#  ' Barber',
#  'Common Blue',
#  'Rosa &#39;Princesse de Sagan&#39;',
#  ' Waffle',
#  ' Mushroom',
#  ' Sesame Oil',
#  'Montestrutto',
#  ' White Sand',
#  ' Prickly',
#  ' Sleep',
#  'Manicure',
#  ' Calico Cat',
#  ' Thuja',
#  'Cctv',
#  ' Surprised',
#  ' Planets',
#  'Ski',
#  ' A Heart',
#  'Sunset',
#  'Happy Birthday',
#  ' Crypto',
#  'Landmark 81',
#  ' Spinning',
#  ' Heat',
#  ' Vintage Tea Cup',
#  ' Montmartre',
#  'Palm Warbler',
#  'Christmas spreads the message of peace and harmony!',
#  ' Paint',
#  'Tartan Track',
#  'Dune',
#  'Selfie',
#  'Railroad Tracks',
#  'Hoverfly',
#  'Dam',
#  'Rosette',
#  'Film',
#  ' Warming',
#  'Paraglider',
#  ' Incandescent',
#  ' Youtube',
#  ' Dreamy',
#  ' Red Wine',
#  ' Japanese Cherry',
#  ' Toore',
#  ' Phacelia',
#  'Aster',
#  ' Lizards',
#  ' Fireworks',
#  ' Twin Tower',
#  ' Mauritius',
#  ' Athletics',
#  ' Computer',
#  'Walking',
#  ' Maria',
#  'Smartphone',
#  ' Bauen',
#  'Mask',
#  ' Congratulation',
#  ' Fear',
#  'Tarot',
#  'Buddhist',
#  ' Mountain Huts',
#  'Movie Projector',
#  'Alpine Village',
#  ' Sidewalk',
#  ' Peace And Quiet',
#  ' Glow',
#  ' Piggyback',
#  ' Goal',
#  ' Egyptian',
#  ' Historical',
#  ' Wrought Iron Art',
#  ' Red Fruit',
#  ' Sainfoin',
#  ' Dried Artichoke',
#  'Fortification',
#  ' Red Panda',
#  ' Nagasaki was the only port opened to foreign countries.',
#  ' Condensation',
#  'Webinar',
#  ' Vintage Tv',
#  ' Homeless',
#  'Sapporo Soup Curry',
#  ' Future',
#  'Make A Phone Call',
#  'Poppies',
#  'Brick',
#  ' Hummingbird',
#  ' Vietnamese',
#  'Torrent',
#  ' Study',
#  ' Cherry Blossoms',
#  'Marmot',
#  ' Press',
#  ' April',
#  ' Relaxing',
#  ' Coal Tit',
#  'Great Egret',
#  ' Yellow Rose',
#  ' Obesity',
#  ' Communication',
#  ' Seoul',
#  ' Flu',
#  'Inspired by: pen_ash https://pixabay.com/photos/red-panda-lesser-panda-wildlife-4366264/',
#  ' Needlework',
#  'Speyer Bridge',
#  ' Visa Card',
#  ' Motocross',
#  ' Ring',
#  ' Königssee',
#  ' Strawberries',
#  ' Aisle',
#  ' Knitting',
#  ' Light Fixture',
#  'Thai Boxer',
#  'Plaster',
#  'Pets',
#  'Melon',
#  ' Envelope',
#  'Cookie Cutter',
#  ' Devil Wall',
#  'Yellow Daylily',
#  ' Bud',
#  ' Firefighting',
#  ' European Robin',
#  'Yellow Flower',
#  ' War Zone',
#  ' Citadel',
#  ' Insects',
#  ' Angels',
#  ' Last Supper',
#  'Greylag Goose',
#  'Hippopotamus',
#  ' Flying',
#  ' Northern Lights',
#  ' A Book',
#  ' Mouse',
#  ' Horned',
#  'Antalya',
#  ' Edinburgh',
#  'Statue',
#  'Fir Tree',
#  'Selva Di Cadore',
#  ' Diversity',
#  ' Gnome',
#  ' Point',
#  ' Eyes',
#  ' Rocks',
#  ' Macropod',
#  'Soy',
#  'Beehives',
#  ' Doggy',
#  'Barber Shop',
#  'Menu',
#  'Binoculars',
#  ' Air Traffic',
#  ' Place Of Work',
#  'Cotoneaster',
#  'China',
#  ' Chemistry',
#  ' Birthday',
#  ' Fork',
#  ' Mount Fuji',
#  ' and study etc.',
#  ' Primates',
#  ' Mother Mary',
#  ' Branches',
#  ' Hamadryas Baboon',
#  ' Bbq',
#  ' South-Africa',
#  ' Seamless',
#  ' Cupcakes',
#  ' Marigold',
#  ' Blue Hour',
#  ' Eyelash',
#  ' Lampion Flower',
#  'Fountain',
#  ' Cranes',
#  'Baby Elephant',
#  ' Curls',
#  ' Ships',
#  ' Patterns',
#  ' Creek',
#  'Lion',
#  ' Worship',
#  ' Austria',
#  ' Croissant',
#  ' Game Console',
#  'Scarce Swallowtail',
#  'Santorini',
#  ' White',
#  'Nepal',
#  ' Peace Sign',
#  ' Badge',
#  'Holy Quran',
#  'Beautiful sunset in Myrtle Beach South Carolina',
#  "Saint Mark'S Basilica",
#  'Es gibt Wege die gehe ich immer wieder. Dieser ist einer davon',
#  'Diary',
#  ' White Mushroom',
#  ' Steam',
#  ' Rice Grains',
#  'Cowslips',
#  ' China',
#  ' Telephone',
#  'Landscape',
#  ' Hinduism',
#  ' Pillowcases',
#  ' Lawyer',
#  'Bentley',
#  'Thai Food',
#  'Foal',
#  ' Black Dog',
#  'Apple Cider',
#  ' Bellflower',
#  ' Foliage',
#  ' Tattoo',
#  ' Red Tulips',
#  ' 1891. In 1906 she was en route from Peru to Geelong',
#  ' Elf',
#  ' Pathway',
#  'Shaking Hands',
#  ' Arachnid',
#  ' Professional',
#  ' Scrapbooking',
#  ' Horse Eye',
#  'Bark',
#  'Nanking Cherry',
#  'Garda',
#  'Tulip Flowers',
#  ' Decoupage Eggs',
#  ' Library',
#  ' Tables',
#  ' Flying Carpet',
#  ' Carbon Dioxide',
#  ' Germ',
#  ' Cut Out',
#  'Sailing Ship',
#  ' Direction',
#  ' Bergsee',
#  'Doors',
#  'Time',
#  ' Religious',
#  'Tree',
#  'Bullying',
#  'Farm',
#  ' Young Dog',
#  ' Lightness',
#  ' Ilex',
#  ' Claws',
#  ' Set',
#  'Panoramablick von einer Wanderung auf den Pitschenberg',
#  'Eggplant',
#  'Grape Hyacinth',
#  ' Arch Bridge',
#  'Big Sur',
#  ' Dry',
#  ' Frosty',
#  ' Covered',
#  ' Starfish',
#  'Boat House',
#  'Blue Rock Thrush',
#  'Lilac Breasted Roller',
#  ' Man',
#  ' Scales',
#  ' Piran',
#  ' Moscow',
#  ' Slope',
#  ' Wooden Spoon',
#  ' Museum',
#  'Ginkgo',
#  ' Mountain Peak',
#  ' Luxury Bathroom',
#  ' Fledgling',
#  'Light Bulbs',
#  ' Ale',
#  ' Pitcher',
#  'Cliffs',
#  ' Waterway',
#  'Rider',
#  ' Pots',
#  ' Chapel',
#  'Mirroring',
#  'Lighthouse',
#  'Fuel',
#  'Japan is an island country. Her area has only 370 thousand square kilometers',
#  'Cotswolds',
#  ' Pouring',
#  'Shoes',
#  ' To The Piz De Molinera',
#  ' Black Women',
#  ' Rocky',
#  ' Red',
#  ' Statues',
#  'Chaffinch',
#  ' Thirst',
#  ' Tatra Chamois',
#  'death valley',
#  ' Northern Cardinal',
#  'Residential Complex',
#  'Hoarfrost',
#  ' Market',
#  'Ice',
#  'Hare',
#  ' Burma',
#  'Wine Glass',
#  ' Handyman',
#  'Achievement',
#  ' Kyoto',
#  ' Texas 2021',
#  ' Kitesurfer',
#  ' House Sparrow',
#  ' England',
#  ' Chalk Board',
#  ' it becomes very popular.',
#  'Reiter',
#  ' Plate',
#  'The use of a copyrighted photo requires the name of the author (Henryk Niestrój) or payment. Minimum fee of $ 1 via PayPal to account nhenric@gmail.com (Coffee button)',
#  ' Young',
#  ' Frankfurt',
#  ' Pink Woodsorrel',
#  'Pool',
#  ' Sketch',
#  ' Gothic',
#  ' Box',
#  ' Earphones',
#  ' Gingerbread House',
#  'Waitress with a roll of paper preparing to clean the tables on a terrace-restaurant',
#  ' E-Commerce',
#  ' Doll',
#  ' Cartology',
#  'Luggage',
#  ' The Wizard',
#  ' Cornflower',
#  ' Emirates',
#  ' Pose',
#  'Railway Station',
#  'Succulent',
#  ' Bedrock',
#  ' Tealights',
#  ' Waffles',
#  ' Chimp',
#  'assorted color smiley illustration',
#  ' Camel',
#  ' Girlfriend',
#  ' Groove',
#  'Vector Notepad',
#  ' Brush',
#  ' Grasses',
#  ' Kite',
#  ' Ipad',
#  'Dare',
#  ' Windsurfers',
#  ' Wicks',
#  ' To Discuss',
#  ' Enterprising',
#  'Petunias',
#  ' Coffeepot',
#  ' Strength',
#  ' Impact',
#  ' Loch',
#  ' Band',
#  ' Muddy Puppy',
#  'Startup',
#  ' Finch',
#  ' River Valley',
#  'Pelicans',
#  ' Whisk',
#  'Tavern',
#  ' Corvette',
#  ' Wrapped',
#  'Russian Blue Cat',
#  ' Small',
#  ' 3D Animation',
#  'Bike',
#  ' Media',
#  ' Namibia',
#  ' Nostril',
#  ' Eat',
#  'Budapest',
#  ' Wild Life',
#  ' Hyacinth',
#  ' Reflection',
#  'Hibiscus',
#  ' Bath',
#  'Child',
#  'Rural',
#  ' Burglary',
#  ' Hot Drink',
#  ' Pores',
#  'Sea Shell',
#  'Young Plant',
#  ' Hern',
#  ' Free Climbing',
#  ' Slip-Up',
#  ' Wildlife',
#  ' Scarlet Ibis',
#  ' Helmet',
#  'Tuna',
#  ' Idaho',
#  'Barbecue',
#  'Australian Wood Duck',
#  ' Dock',
#  ' Annoyed',
#  'Life',
#  ' Furniture',
#  ' Eyeball',
#  ' City Life',
#  ' Watering Hole',
#  ' Formulas',
#  ' Gift Boxes',
#  'Elderly',
#  'Brno',
#  ' Apartment',
#  ' Wedding Dress',
#  ' Blockchain',
#  'Concrete',
#  'Windshield',
#  'Contemplating',
#  ' Used',
#  'Valais',
#  ' Rural',
#  'Winding Road',
#  ' Clownfish',
#  ' Fliying',
#  ' Christmas Ball',
#  ' Pink Roses',
#  ' Pour',
#  ' Canada Goose',
#  ' Moldova',
#  'Dough',
#  ' Wear',
#  ' Wet',
#  'Flakes',
#  ' Pages',
#  'Valentinstag',
#  ' Rose Bloom',
#  ' Journey',
#  'Pulses',
#  'Farming',
#  'Friendship',
#  ' Purebred',
#  'Bumblebee',
#  ' Lagoon',
#  ' Pancake Week',
#  ...}

# %%
for i in tqdm(tag):
    try :
        os.mkdir('dataset/'+(i.strip()))
    except:
        pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9610/9610 [00:00<00:00, 18138.81it/s]

# %%
from shutil import copy

# %%
error_incr = 0
for tags, img in tqdm(zip(data['Tags'],data['Location'])):
    #print(tags)
    #print(img)
    src = img

    tag = ['dataset/' + tag.strip() + '/' for tag in tags.split(',')]
    #print(tag)

    for i in tag:
        if not os.path.exists(tag_dir):
            os.makedirs(tag_dir)
            
        des = os.path.join(i, os.path.basename(img))
        try:
            copy(src, des)
        except Exception as e:
            error_incr += 1
            print(f"Error copying {src} to {des}: {e}")
# Out:
# 116it [00:00, 563.88it/s]
# Clouds, Sky, Atmosphere, Blue Sky
# Collection/clouds-7050884__480.jpg
# ['dataset/Clouds/', 'dataset/Sky/', 'dataset/Atmosphere/', 'dataset/Blue Sky/']
# Bird, Ornithology, Hummingbird
# Collection/bird-7117346__340.jpg
# ['dataset/Bird/', 'dataset/Ornithology/', 'dataset/Hummingbird/']
# Sea, Rainbow, Rainfall, Subtropical
# Collection/sea-7039471__340.jpg
# ['dataset/Sea/', 'dataset/Rainbow/', 'dataset/Rainfall/', 'dataset/Subtropical/']
# Cherry Blossoms, Road, Japan, Sakura
# Collection/cherry-blossoms-7110279__340.jpg
# ['dataset/Cherry Blossoms/', 'dataset/Road/', 'dataset/Japan/', 'dataset/Sakura/']
# Cape Marguerite, Flower, Plant
# Collection/cape-marguerite-7121992__340.jpg
# ['dataset/Cape Marguerite/', 'dataset/Flower/', 'dataset/Plant/']
# Relaxing Rest Under The Tree
# Collection/tree-6792528__340.jpg
# ['dataset/Relaxing Rest Under The Tree/']
# Cottontail Rabbit, Wild Rabbit, Grass
# Collection/cottontail-rabbit-7116707__340.jpg
# ['dataset/Cottontail Rabbit/', 'dataset/Wild Rabbit/', 'dataset/Grass/']
# Crocus, Flowers, Spring, Plant
# Collection/crocus-7079550__340.jpg
# ['dataset/Crocus/', 'dataset/Flowers/', 'dataset/Spring/', 'dataset/Plant/']
# Coffee, Café, Vacation, Drink, Table
# Collection/coffee-7121939__340.jpg
# ['dataset/Coffee/', 'dataset/Café/', 'dataset/Vacation/', 'dataset/Drink/', 'dataset/Table/']
# Waterfall, Fall, Epic, Nature, Light
# Collection/waterfall-7091641__340.jpg
# ['dataset/Waterfall/', 'dataset/Fall/', 'dataset/Epic/', 'dataset/Nature/', 'dataset/Light/']
# Field, Morning, Sunrise, Dawn, Nature
# Collection/field-6574455__340.jpg
# ['dataset/Field/', 'dataset/Morning/', 'dataset/Sunrise/', 'dataset/Dawn/', 'dataset/Nature/']
# Bird, Robin, Birdwatching, Animal
# Collection/bird-7111988__340.jpg
# ['dataset/Bird/', 'dataset/Robin/', 'dataset/Birdwatching/', 'dataset/Animal/']
# Seedlings, Soil, Spring Flowers, Bloom
# Collection/seedlings-7110591__340.jpg
# ['dataset/Seedlings/', 'dataset/Soil/', 'dataset/Spring Flowers/', 'dataset/Bloom/']
# Road, Highway, Countryside, Hills
# Collection/road-7087957__340.jpg
# ['dataset/Road/', 'dataset/Highway/', 'dataset/Countryside/', 'dataset/Hills/']
# Cityscape, Monochrome, Bridge, City
# Collection/cityscape-7095358__340.jpg
# ['dataset/Cityscape/', 'dataset/Monochrome/', 'dataset/Bridge/', 'dataset/City/']
# Sakura, Cherry Blossoms, Spring, Water
# Collection/sakura-7091532__340.jpg
# ['dataset/Sakura/', 'dataset/Cherry Blossoms/', 'dataset/Spring/', 'dataset/Water/']
# Background, Easter, Eggs, Template, Art
# Collection/background-7105471__480.jpg
# ['dataset/Background/', 'dataset/Easter/', 'dataset/Eggs/', 'dataset/Template/', 'dataset/Art/']
# Bird, Indian Chat, Ornithology, Species
# Collection/bird-6983434__340.jpg
# ['dataset/Bird/', 'dataset/Indian Chat/', 'dataset/Ornithology/', 'dataset/Species/']
# Town, Night, Winter, Village, Season
# Collection/town-6947538__340.jpg
# ['dataset/Town/', 'dataset/Night/', 'dataset/Winter/', 'dataset/Village/', 'dataset/Season/']
# Flower, Viola, Pansy, Blossom, Bloom
# Collection/flower-7121955__340.jpg
# ['dataset/Flower/', 'dataset/Viola/', 'dataset/Pansy/', 'dataset/Blossom/', 'dataset/Bloom/']
# Port, Lake, Architecture, Vacations
# Collection/port-6587129__340.jpg
# ['dataset/Port/', 'dataset/Lake/', 'dataset/Architecture/', 'dataset/Vacations/']
# Sunflowers, Flowers, Plant
# Collection/sunflowers-7071449__340.jpg
# ['dataset/Sunflowers/', 'dataset/Flowers/', 'dataset/Plant/']
# Coffee, Spring, Flowers, Morning
# Collection/coffee-7098126__340.jpg
# ['dataset/Coffee/', 'dataset/Spring/', 'dataset/Flowers/', 'dataset/Morning/']
# Roys Peak, Wanaka, Lake, Mountains
# Collection/roys-peak-7008528__340.jpg
# ['dataset/Roys Peak/', 'dataset/Wanaka/', 'dataset/Lake/', 'dataset/Mountains/']
# Thank you, everyone. Thank you for many downloads and likes.
# Collection/mountain-6815304__340.jpg
# ['dataset/Thank you/', 'dataset/everyone. Thank you for many downloads and likes./']
# Nature, Beach, Outdoors, Exploration
# Collection/nature-6565499__340.jpg
# ['dataset/Nature/', 'dataset/Beach/', 'dataset/Outdoors/', 'dataset/Exploration/']
# The Danish West Coast of Jutland. Shot during sunset.
# Collection/nature-7045125__340.jpg
# ['dataset/The Danish West Coast of Jutland. Shot during sunset./']
# Gentoo Penguin, Penguin, Bird, Animal
# Collection/gentoo-penguin-7073391__340.jpg
# ['dataset/Gentoo Penguin/', 'dataset/Penguin/', 'dataset/Bird/', 'dataset/Animal/']
# Lantern, Sea, Heaven, Beach, Water, Tree
# Collection/lantern-6826698__340.jpg
# ['dataset/Lantern/', 'dataset/Sea/', 'dataset/Heaven/', 'dataset/Beach/', 'dataset/Water/', 'dataset/Tree/']
# Easter, Spring, Easter Bunny
# Collection/easter-7108066__340.jpg
# ['dataset/Easter/', 'dataset/Spring/', 'dataset/Easter Bunny/']
# green trees on brown rock formation on lake during daytime
# Collection/nature-3082832__340.jpg
# ['dataset/green trees on brown rock formation on lake during daytime/']
# Tourist Attraction, Eiffel Tower, Travel
# Collection/tourist-attraction-7037967__340.jpg
# ['dataset/Tourist Attraction/', 'dataset/Eiffel Tower/', 'dataset/Travel/']
# Menhir, Stones, Clouds, Standing Stones
# Collection/menhir-7118382__480.jpg
# ['dataset/Menhir/', 'dataset/Stones/', 'dataset/Clouds/', 'dataset/Standing Stones/']
# Road, Trees, Winter, Frost, Snow, Path
# Collection/road-6935773__340.jpg
# ['dataset/Road/', 'dataset/Trees/', 'dataset/Winter/', 'dataset/Frost/', 'dataset/Snow/', 'dataset/Path/']
# Bird, Woodpecker
# Collection/bird-7122753__340.jpg
# ['dataset/Bird/', 'dataset/Woodpecker/']
# Tape, Cassette, Music, Retro, Classic
# Collection/tape-6824489__340.jpg
# ['dataset/Tape/', 'dataset/Cassette/', 'dataset/Music/', 'dataset/Retro/', 'dataset/Classic/']
# Wind Mills, Energy, Clouds, Power
# Collection/wind-mills-6928590__340.jpg
# ['dataset/Wind Mills/', 'dataset/Energy/', 'dataset/Clouds/', 'dataset/Power/']
# Travel, Tourism, Square, Tartini, Piran
# Collection/travel-7014427__340.jpg
# ['dataset/Travel/', 'dataset/Tourism/', 'dataset/Square/', 'dataset/Tartini/', 'dataset/Piran/']
# Easter Eggs, Colored Eggs, Nest, Eggs
# Collection/easter-eggs-7124718__340.jpg
# ['dataset/Easter Eggs/', 'dataset/Colored Eggs/', 'dataset/Nest/', 'dataset/Eggs/']
# Winter, Season, Nature, Outdoors, Travel
# Collection/winter-7000429__340.jpg
# ['dataset/Winter/', 'dataset/Season/', 'dataset/Nature/', 'dataset/Outdoors/', 'dataset/Travel/']
# Glacier, Dying Glaciers, Melting Glacier
# Collection/glacier-7125386__340.jpg
# ['dataset/Glacier/', 'dataset/Dying Glaciers/', 'dataset/Melting Glacier/']
# Forest, Jungle, Tropical, Green, Nature
# Collection/forest-6761846__340.jpg
# ['dataset/Forest/', 'dataset/Jungle/', 'dataset/Tropical/', 'dataset/Green/', 'dataset/Nature/']
# Tulip, Flower, Bloom, Blossom, Petals
# Collection/tulip-6994245__340.jpg
# ['dataset/Tulip/', 'dataset/Flower/', 'dataset/Bloom/', 'dataset/Blossom/', 'dataset/Petals/']
# Flowers, Pink Flowers, Petals
# Collection/flowers-7117461__340.jpg
# ['dataset/Flowers/', 'dataset/Pink Flowers/', 'dataset/Petals/']
# Passiflora, Passion Flower, Flower
# Collection/passiflora-7027917__340.jpg
# ['dataset/Passiflora/', 'dataset/Passion Flower/', 'dataset/Flower/']
# Prayer, Faith, Religion, Hope, Blessing
# Collection/prayer-6764197__340.jpg
# ['dataset/Prayer/', 'dataset/Faith/', 'dataset/Religion/', 'dataset/Hope/', 'dataset/Blessing/']
# Galaxy, Space, Universe, Star, Cosmos
# Collection/galaxy-7121195__340.jpg
# ['dataset/Galaxy/', 'dataset/Space/', 'dataset/Universe/', 'dataset/Star/', 'dataset/Cosmos/']
# Dragonfly, Nature, Insect, Macro
# Collection/dragonfly-7102558__480.jpg
# ['dataset/Dragonfly/', 'dataset/Nature/', 'dataset/Insect/', 'dataset/Macro/']
# Budapest, Hungary, Architecture, Church
# Collection/budapest-6928973__340.jpg
# ['dataset/Budapest/', 'dataset/Hungary/', 'dataset/Architecture/', 'dataset/Church/']
# Trees, Forest, Leaves, Foliage, Magic
# Collection/trees-7072255__340.jpg
# ['dataset/Trees/', 'dataset/Forest/', 'dataset/Leaves/', 'dataset/Foliage/', 'dataset/Magic/']
# Das war bei meinem Aufenthalt in der Reha Klinik Klausenbach. Die liegt in Nordrach genauer in der Kolonie! Es wunderbarer Ort. Wie gemacht für die Erholung! Es gibt einen tollen Film mit Heike Makatsch als Dr. Hope Bridges Adams Lehmann als erste Ärztin 1880!
# Collection/hotel-6862159__340.jpg
# ['dataset/Das war bei meinem Aufenthalt in der Reha Klinik Klausenbach. Die liegt in Nordrach genauer in der Kolonie! Es wunderbarer Ort. Wie gemacht für die Erholung! Es gibt einen tollen Film mit Heike Makatsch als Dr. Hope Bridges Adams Lehmann als erste Ärztin 1880!/']
# Error copying Collection/hotel-6862159__340.jpg to dataset/Das war bei meinem Aufenthalt in der Reha Klinik Klausenbach. Die liegt in Nordrach genauer in der Kolonie! Es wunderbarer Ort. Wie gemacht für die Erholung! Es gibt einen tollen Film mit Heike Makatsch als Dr. Hope Bridges Adams Lehmann als erste Ärztin 1880!/hotel-6862159__340.jpg: [Errno 2] No such file or directory: 'dataset/Das war bei meinem Aufenthalt in der Reha Klinik Klausenbach. Die liegt in Nordrach genauer in der Kolonie! Es wunderbarer Ort. Wie gemacht für die Erholung! Es gibt einen tollen Film mit Heike Makatsch als Dr. Hope Bridges Adams Lehmann als erste Ärztin 1880!/hotel-6862159__340.jpg'
# This is a tree plantation near the summit of Mt. Hiei (848m). The site is owned and managed by Enryaku-ji temple. The trees are Hinoki cypress, which is very useful for constructions and crafts. In the future, the woods are used for reconstruction of old temple buildings.
# Collection/landscape-6887936__340.jpg
# ['dataset/This is a tree plantation near the summit of Mt. Hiei (848m). The site is owned and managed by Enryaku-ji temple. The trees are Hinoki cypress/', 'dataset/which is very useful for constructions and crafts. In the future/', 'dataset/the woods are used for reconstruction of old temple buildings./']
# Flowers, Growth, Nature, Blossom, Bloom
# Collection/flowers-7117464__340.jpg
# ['dataset/Flowers/', 'dataset/Growth/', 'dataset/Nature/', 'dataset/Blossom/', 'dataset/Bloom/']
# My baby (or babies) are due any day! ☺️
# Collection/cow-6992475__340.jpg
# ['dataset/My baby (or babies) are due any day! ☺️/']
# Port, Ship, Boat, Sweden, Sea
# Collection/port-6910972__340.jpg
# ['dataset/Port/', 'dataset/Ship/', 'dataset/Boat/', 'dataset/Sweden/', 'dataset/Sea/']
# Photographed on February 29, 2021 - the Pixabay license FORBIDS selling images as is on stock sites or elsewhere. Here is a link to the licence: https://pixabay.com/service/license/
# Collection/heron-7120365__340.jpg
# ['dataset/Photographed on February 29/', 'dataset/2021 - the Pixabay license FORBIDS selling images as is on stock sites or elsewhere. Here is a link to the licence: https://pixabay.com/service/license//']
# Error copying Collection/heron-7120365__340.jpg to dataset/2021 - the Pixabay license FORBIDS selling images as is on stock sites or elsewhere. Here is a link to the licence: https://pixabay.com/service/license//heron-7120365__340.jpg: [Errno 22] Invalid argument: 'dataset/2021 - the Pixabay license FORBIDS selling images as is on stock sites or elsewhere. Here is a link to the licence: https://pixabay.com/service/license//heron-7120365__340.jpg'
# Leaf, Nature, Autumn, Fall, Season, Leaf
# Collection/leaf-6760484__340.jpg
# ['dataset/Leaf/', 'dataset/Nature/', 'dataset/Autumn/', 'dataset/Fall/', 'dataset/Season/', 'dataset/Leaf/']
# Water, Trolltunga, Ringedalsvannet
# Collection/water-6579313__340.jpg
# ['dataset/Water/', 'dataset/Trolltunga/', 'dataset/Ringedalsvannet/']
# Cat, European Shorthair, Pet, Feline
# Collection/cat-6838844__340.jpg
# ['dataset/Cat/', 'dataset/European Shorthair/', 'dataset/Pet/', 'dataset/Feline/']
# Baboon, Animal, Wildlife, Gesture
# Collection/baboon-6969935__340.jpg
# ['dataset/Baboon/', 'dataset/Animal/', 'dataset/Wildlife/', 'dataset/Gesture/']
# Savoy, Cabbage, Vegetables, Carrots
# Collection/savoy-7124124__340.jpg
# ['dataset/Savoy/', 'dataset/Cabbage/', 'dataset/Vegetables/', 'dataset/Carrots/']
# Koi Fish, Fish, Pond, Water, Koi
# Collection/koi-fish-7071556__480.jpg
# ['dataset/Koi Fish/', 'dataset/Fish/', 'dataset/Pond/', 'dataset/Water/', 'dataset/Koi/']
# Family, Beach, People, Ocean, Family
# Collection/family-6398107__340.jpg
# ['dataset/Family/', 'dataset/Beach/', 'dataset/People/', 'dataset/Ocean/', 'dataset/Family/']
# Elephant, Baby Elephant, Animals
# Collection/elephant-7036431__340.jpg
# ['dataset/Elephant/', 'dataset/Baby Elephant/', 'dataset/Animals/']
# Savoy, Cabbage, Vegetables, Carrots
# Collection/savoy-7124124__340.jpg
# ['dataset/Savoy/', 'dataset/Cabbage/', 'dataset/Vegetables/', 'dataset/Carrots/']
# Add a description (optional)
# Collection/ranunculus-7123057__340.jpg
# ['dataset/Add a description (optional)/']
# Great Cormorant, Bird
# Collection/great-cormorant-7119976__340.jpg
# ['dataset/Great Cormorant/', 'dataset/Bird/']
# Flower, Daffodil, Petals, Plant
# Collection/flower-7124081__340.jpg
# ['dataset/Flower/', 'dataset/Daffodil/', 'dataset/Petals/', 'dataset/Plant/']
# Sea, Waves, Storm, Sky, Clouds, Overcast
# Collection/sea-6975501__340.jpg
# ['dataset/Sea/', 'dataset/Waves/', 'dataset/Storm/', 'dataset/Sky/', 'dataset/Clouds/', 'dataset/Overcast/']
# Fantasy, Butterflies, Mushrooms, Forest
# Collection/fantasy-2049567__340.jpg
# ['dataset/Fantasy/', 'dataset/Butterflies/', 'dataset/Mushrooms/', 'dataset/Forest/']
# Child, Boy, Flowers, Meadow, Cute, Kid
# Collection/child-7070570__340.jpg
# ['dataset/Child/', 'dataset/Boy/', 'dataset/Flowers/', 'dataset/Meadow/', 'dataset/Cute/', 'dataset/Kid/']
# Grass, Plants, Oats, Ear, Barley
# Collection/grass-7115462__340.jpg
# ['dataset/Grass/', 'dataset/Plants/', 'dataset/Oats/', 'dataset/Ear/', 'dataset/Barley/']
# Book, Literature, Reading, Library
# Collection/book-6709160__340.jpg
# ['dataset/Book/', 'dataset/Literature/', 'dataset/Reading/', 'dataset/Library/']
# Wood Anemones, Anemone, Buttercups
# Collection/wood-anemones-7115637__340.jpg
# ['dataset/Wood Anemones/', 'dataset/Anemone/', 'dataset/Buttercups/']
# white and red boat on beach during daytime
# Collection/polynesia-3021072__340.jpg
# ['dataset/white and red boat on beach during daytime/']
# Flower, Bee, Pollination, Bloom, Insect
# Collection/flower-7108476__340.jpg
# ['dataset/Flower/', 'dataset/Bee/', 'dataset/Pollination/', 'dataset/Bloom/', 'dataset/Insect/']
# Letter Box, Email Delivery, Post Office
# Collection/letter-box-7126374__480.jpg
# ['dataset/Letter Box/', 'dataset/Email Delivery/', 'dataset/Post Office/']
# Calm Lake At Sunset
# Collection/sunset-6945937__340.jpg
# ['dataset/Calm Lake At Sunset/']
# Illustration, sunflowers farming,
# Collection/sunflowers-7112463__340.jpg
# ['dataset/Illustration/', 'dataset/sunflowers farming/', 'dataset//']
# Beach, Sand, Sea, North Sea, Winter
# Collection/beach-7023446__340.jpg
# ['dataset/Beach/', 'dataset/Sand/', 'dataset/Sea/', 'dataset/North Sea/', 'dataset/Winter/']
# Trees, Nature, Winter, Season, Outdoors
# Collection/trees-6935614__340.jpg
# ['dataset/Trees/', 'dataset/Nature/', 'dataset/Winter/', 'dataset/Season/', 'dataset/Outdoors/']
# Flower, Rose, Bloom, Blossom, Botany
# Collection/flower-7043267__340.jpg
# ['dataset/Flower/', 'dataset/Rose/', 'dataset/Bloom/', 'dataset/Blossom/', 'dataset/Botany/']
# Winter, Frost, Nature, Texture, Macro
# Collection/winter-6897046__340.jpg
# ['dataset/Winter/', 'dataset/Frost/', 'dataset/Nature/', 'dataset/Texture/', 'dataset/Macro/']
# Bird, Blackbird, Ornithology, Species
# Collection/bird-6899457__340.jpg
# ['dataset/Bird/', 'dataset/Blackbird/', 'dataset/Ornithology/', 'dataset/Species/']
# Trees, Rural, Clouds, Nature, Landscape
# Collection/trees-7123499__340.jpg
# ['dataset/Trees/', 'dataset/Rural/', 'dataset/Clouds/', 'dataset/Nature/', 'dataset/Landscape/']
# Coffee, Pencils, Eraser, Office
# Collection/coffee-6943139__340.jpg
# ['dataset/Coffee/', 'dataset/Pencils/', 'dataset/Eraser/', 'dataset/Office/']
# Lotus, Flower, Lotus Flower, Pink Flower
# Collection/lotus-6474572__340.jpg
# ['dataset/Lotus/', 'dataset/Flower/', 'dataset/Lotus Flower/', 'dataset/Pink Flower/']
# Es sind noch Plätze frei…
# Collection/bus-7105041__340.jpg
# ['dataset/Es sind noch Plätze frei…/']
# Crocus, Flowers, Plants, Purple Crocus
# Collection/crocus-6955548__340.jpg
# ['dataset/Crocus/', 'dataset/Flowers/', 'dataset/Plants/', 'dataset/Purple Crocus/']
# Taken in March 21, 2022
# Collection/birds-7125333__340.jpg
# ['dataset/Taken in March 21/', 'dataset/2022/']
# Mountain, Summit, Forest, Winter, Clouds
# Collection/mountain-6867146__340.jpg
# ['dataset/Mountain/', 'dataset/Summit/', 'dataset/Forest/', 'dataset/Winter/', 'dataset/Clouds/']
# Ice Cream Cone, Ice Squirrel, Flower
# Collection/ice-cream-cone-7122797__340.jpg
# ['dataset/Ice Cream Cone/', 'dataset/Ice Squirrel/', 'dataset/Flower/']
# Flower, Magnolia, Tree, Spring Flowers
# Collection/flower-7121113__480.jpg
# ['dataset/Flower/', 'dataset/Magnolia/', 'dataset/Tree/', 'dataset/Spring Flowers/']
# Flowers, Bouquet, Garden
# Collection/flowers-7115215__340.jpg
# ['dataset/Flowers/', 'dataset/Bouquet/', 'dataset/Garden/']
# Help Ukraine! Stop the war!
# Collection/winter-7046891__340.jpg
# ['dataset/Help Ukraine! Stop the war!/']
# Jay, Bird, Animal, Snow, Winter
# Collection/jay-7108357__340.jpg
# ['dataset/Jay/', 'dataset/Bird/', 'dataset/Animal/', 'dataset/Snow/', 'dataset/Winter/']
# Built in 1300-1400, the former Augustinian (Les Augustins, in French) convent in Toulouse (France) has become a museum.
# Collection/dungeon-7120925__340.jpg
# ['dataset/Built in 1300-1400/', 'dataset/the former Augustinian (Les Augustins/', 'dataset/in French) convent in Toulouse (France) has become a museum./']
# Birds, Egyptian Goslings, Waterfowl
# Collection/birds-7125327__340.jpg
# ['dataset/Birds/', 'dataset/Egyptian Goslings/', 'dataset/Waterfowl/']
# Peach Blossom, Flowers, Branch, Tree
# Collection/peach-blossom-7115083__340.jpg
# ['dataset/Peach Blossom/', 'dataset/Flowers/', 'dataset/Branch/', 'dataset/Tree/']
# Happy New Year, 2022, Regards, New Year
# Collection/happy-new-year-6838276__340.jpg
# ['dataset/Happy New Year/', 'dataset/2022/', 'dataset/Regards/', 'dataset/New Year/']
# Flowers, Botany, Quince
# Collection/flowers-7109567__340.jpg
# ['dataset/Flowers/', 'dataset/Botany/', 'dataset/Quince/']
# Astronomy, Bright, Constellation, Dark
# Collection/astronomy-1867616__340.jpg
# ['dataset/Astronomy/', 'dataset/Bright/', 'dataset/Constellation/', 'dataset/Dark/']
# Flowers, Bloom, Botany, Blossom, Nature
# Collection/flowers-7012876__340.jpg
# ['dataset/Flowers/', 'dataset/Bloom/', 'dataset/Botany/', 'dataset/Blossom/', 'dataset/Nature/']
# Path, Rural, Nature, Road, Countryside
# Collection/path-6567149__340.jpg
# ['dataset/Path/', 'dataset/Rural/', 'dataset/Nature/', 'dataset/Road/', 'dataset/Countryside/']
# Bird, Ibis, Spiny Ibis, Ornithology
# Collection/bird-7012586__340.jpg
# ['dataset/Bird/', 'dataset/Ibis/', 'dataset/Spiny Ibis/', 'dataset/Ornithology/']
# Baby, Girl, Portrait, Child, Daughter
# Collection/baby-6578335__340.jpg
# ['dataset/Baby/', 'dataset/Girl/', 'dataset/Portrait/', 'dataset/Child/', 'dataset/Daughter/']
# Christmas Tree, Ornaments, Christmas
# Collection/christmas-tree-6883263__340.jpg
# ['dataset/Christmas Tree/', 'dataset/Ornaments/', 'dataset/Christmas/']
# Sunrise, Mountains, Fog, Swabian Jura
# Collection/sunrise-6670717__340.jpg
# ['dataset/Sunrise/', 'dataset/Mountains/', 'dataset/Fog/', 'dataset/Swabian Jura/']
# Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…
# Collection/giant-lily-7114496__480.jpg
# ['dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/']
# Error copying Collection/giant-lily-7114496__480.jpg to dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/giant-lily-7114496__480.jpg: [Errno 2] No such file or directory: 'dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/giant-lily-7114496__480.jpg'
# Postcard, Greeting Card, Peacocks, Birds
# Collection/postcard-7116453__340.jpg
# ['dataset/Postcard/', 'dataset/Greeting Card/', 'dataset/Peacocks/', 'dataset/Birds/']
# Bird, Great Egret, Ornithology, Species
# Collection/bird-6965228__340.jpg
# ['dataset/Bird/', 'dataset/Great Egret/', 'dataset/Ornithology/', 'dataset/Species/']
# Flowers, Grass, Coast, Cliff, Beach, Sea
# Collection/flowers-6928749__340.jpg
# ['dataset/Flowers/', 'dataset/Grass/', 'dataset/Coast/', 'dataset/Cliff/', 'dataset/Beach/', 'dataset/Sea/']
# Flower, Dandelion, Wildflower, Seeds
# Collection/flower-6879399__340.jpg
# ['dataset/Flower/', 'dataset/Dandelion/', 'dataset/Wildflower/', 'dataset/Seeds/']
# Book, Page, Man, Stop, Shades, Paper
# Collection/book-6871220__340.jpg
# ['dataset/Book/', 'dataset/Page/', 'dataset/Man/', 'dataset/Stop/', 'dataset/Shades/', 'dataset/Paper/']
# Castle, Monument, Park, Building
# Collection/castle-6566978__340.jpg
# ['dataset/Castle/', 'dataset/Monument/', 'dataset/Park/', 'dataset/Building/']
# Birds, Greylag Goose, Ornithology
# Collection/birds-7113827__340.jpg
# ['dataset/Birds/', 'dataset/Greylag Goose/', 'dataset/Ornithology/']
# 181it [00:00, 597.50it/s]
# Hyacinth, Flowers, Spring, Nature
# Collection/hyacinth-7120098__340.jpg
# ['dataset/Hyacinth/', 'dataset/Flowers/', 'dataset/Spring/', 'dataset/Nature/']
# Bokeh, Light, Background, Pattern, Art
# Collection/bokeh-7112555__340.jpg
# ['dataset/Bokeh/', 'dataset/Light/', 'dataset/Background/', 'dataset/Pattern/', 'dataset/Art/']
# Easter, Easter Bunny, Easter Decoration
# Collection/easter-7106722__340.jpg
# ['dataset/Easter/', 'dataset/Easter Bunny/', 'dataset/Easter Decoration/']
# Desert, Sand, Dunes, Dubai, Native
# Collection/desert-6826299__340.jpg
# ['dataset/Desert/', 'dataset/Sand/', 'dataset/Dunes/', 'dataset/Dubai/', 'dataset/Native/']
# The Piano…
# Collection/pforphoto-7108433__340.jpg
# ['dataset/The Piano…/']
# Tech, Circle, Technology, Abstract
# Collection/tech-5090539__340.jpg
# ['dataset/Tech/', 'dataset/Circle/', 'dataset/Technology/', 'dataset/Abstract/']
# Flowers, Hyacinth, Garden
# Collection/flowers-7115217__340.jpg
# ['dataset/Flowers/', 'dataset/Hyacinth/', 'dataset/Garden/']
# Cherry Blossoms, Pink Flowers, Sakura
# Collection/cherry-blossoms-7096607__340.jpg
# ['dataset/Cherry Blossoms/', 'dataset/Pink Flowers/', 'dataset/Sakura/']
# Coffee, Template, Coffee Stain, Dirty
# Collection/coffee-7119373__480.jpg
# ['dataset/Coffee/', 'dataset/Template/', 'dataset/Coffee Stain/', 'dataset/Dirty/']
# Happy Easter, Spring, Decoration, Theme
# Collection/happy-easter-6988491__340.jpg
# ['dataset/Happy Easter/', 'dataset/Spring/', 'dataset/Decoration/', 'dataset/Theme/']
# Lotus, Flowers, Pond, Lily Pads
# Collection/lotus-6863937__340.jpg
# ['dataset/Lotus/', 'dataset/Flowers/', 'dataset/Pond/', 'dataset/Lily Pads/']
# Ring Tailed Lemur, Lemur, Group, Cub
# Collection/ring-tailed-lemur-6954076__340.jpg
# ['dataset/Ring Tailed Lemur/', 'dataset/Lemur/', 'dataset/Group/', 'dataset/Cub/']
# El estornino pinto, o estornino común, (Sturnus vulgaris)​ es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires.
# Collection/bird-7116757__340.jpg
# ['dataset/El estornino pinto/', 'dataset/o estornino común/', 'dataset/(Sturnus vulgaris)\u200b es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires./']
# Nature, Spruce, Evergreen, Branches
# Collection/nature-6699893__340.jpg
# ['dataset/Nature/', 'dataset/Spruce/', 'dataset/Evergreen/', 'dataset/Branches/']
# Tablets, Drugs, Powder
# Collection/tablets-7118912__340.jpg
# ['dataset/Tablets/', 'dataset/Drugs/', 'dataset/Powder/']
# White Flowers, Flowers, Nature
# Collection/white-flowers-6944139__340.jpg
# ['dataset/White Flowers/', 'dataset/Flowers/', 'dataset/Nature/']
# Cologne, Cathedral, Bridge, Night, River
# Collection/cologne-6624212__340.jpg
# ['dataset/Cologne/', 'dataset/Cathedral/', 'dataset/Bridge/', 'dataset/Night/', 'dataset/River/']
# Road, Forest, Fall, Autumn, Season
# Collection/road-1072823__340.jpg
# ['dataset/Road/', 'dataset/Forest/', 'dataset/Fall/', 'dataset/Autumn/', 'dataset/Season/']
# Bird, Geese, Ornithology, Species, Fauna
# Collection/bird-7118767__340.jpg
# ['dataset/Bird/', 'dataset/Geese/', 'dataset/Ornithology/', 'dataset/Species/', 'dataset/Fauna/']
# Foto von Ende März 2022
# Collection/flowers-7111580__340.jpg
# ['dataset/Foto von Ende März 2022/']
# Mehtab Bagh, India, Taj Mahal, Temple
# Collection/mehtab-bagh-6698669__340.jpg
# ['dataset/Mehtab Bagh/', 'dataset/India/', 'dataset/Taj Mahal/', 'dataset/Temple/']
# Tulips, Flower, Plant, Flora
# Collection/tulips-7120798__340.jpg
# ['dataset/Tulips/', 'dataset/Flower/', 'dataset/Plant/', 'dataset/Flora/']
# Canada Goose, Goose, Swim, Water Bird
# Collection/canada-goose-7110494__340.jpg
# ['dataset/Canada Goose/', 'dataset/Goose/', 'dataset/Swim/', 'dataset/Water Bird/']
# Earth, Planet, Homeland, Mankind
# Collection/earth-7043847__340.jpg
# ['dataset/Earth/', 'dataset/Planet/', 'dataset/Homeland/', 'dataset/Mankind/']
# El estornino pinto, o estornino común, (Sturnus vulgaris)​ es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires.
# Collection/starling-7116759__480.jpg
# ['dataset/El estornino pinto/', 'dataset/o estornino común/', 'dataset/(Sturnus vulgaris)\u200b es una especie de ave passeriforme de la familia Sturnidae nativa del Paleártico. En Argentina fue introducido hace unos años y hoy se reproduce abundantemente en el sudeste de la Provincia de Buenos Aires./']
# Composition, lake view
# Collection/house-7098314__340.jpg
# ['dataset/Composition/', 'dataset/lake view/']
# Bird, Blackbird, Songbird, Fauna, Animal
# Collection/bird-7119983__340.jpg
# ['dataset/Bird/', 'dataset/Blackbird/', 'dataset/Songbird/', 'dataset/Fauna/', 'dataset/Animal/']
# Durian Redstart. In Japan, it is a winter bird, wintering in regions without snow cover and inhabiting flat to low mountain farmlands, residential areas, parks, and riverbanks.
# Collection/bird-7123044__340.jpg
# ['dataset/Durian Redstart. In Japan/', 'dataset/it is a winter bird/', 'dataset/wintering in regions without snow cover and inhabiting flat to low mountain farmlands/', 'dataset/residential areas/', 'dataset/parks/', 'dataset/and riverbanks./']
# Newborn, Baby, Costume, Sleeping
# Collection/newborn-6780840__340.jpg
# ['dataset/Newborn/', 'dataset/Baby/', 'dataset/Costume/', 'dataset/Sleeping/']
# Cat, Grass, Backyard, Outdoors, Kitten
# Collection/cat-7107728__340.jpg
# ['dataset/Cat/', 'dataset/Grass/', 'dataset/Backyard/', 'dataset/Outdoors/', 'dataset/Kitten/']
# Arch, Alley, Street, Road, Eiffel Tower
# Collection/arch-6356637__340.jpg
# ['dataset/Arch/', 'dataset/Alley/', 'dataset/Street/', 'dataset/Road/', 'dataset/Eiffel Tower/']
# Blackbird, Bird, Animal, Worm, Eating
# Collection/blackbird-7083494__340.jpg
# ['dataset/Blackbird/', 'dataset/Bird/', 'dataset/Animal/', 'dataset/Worm/', 'dataset/Eating/']
# Dog, Golden Retriever, Water, Swim, Lake
# Collection/dog-7115247__340.jpg
# ['dataset/Dog/', 'dataset/Golden Retriever/', 'dataset/Water/', 'dataset/Swim/', 'dataset/Lake/']
# Clouds, Sky, Atmosphere, Grey Clouds
# Collection/clouds-7122287__340.jpg
# ['dataset/Clouds/', 'dataset/Sky/', 'dataset/Atmosphere/', 'dataset/Grey Clouds/']
# Flowers, Spring, Seasonal, Nature, Bloom
# Collection/flowers-7127847__340.jpg
# ['dataset/Flowers/', 'dataset/Spring/', 'dataset/Seasonal/', 'dataset/Nature/', 'dataset/Bloom/']
# Flower, Liverflower, Early Bloomer
# Collection/flower-7103109__340.jpg
# ['dataset/Flower/', 'dataset/Liverflower/', 'dataset/Early Bloomer/']
# Car, Beach, Sunset, Desktop Wallpaper
# Collection/car-6293917__340.jpg
# ['dataset/Car/', 'dataset/Beach/', 'dataset/Sunset/', 'dataset/Desktop Wallpaper/']
# Mountain, Summit, Snow, Winter
# Collection/mountain-6734031__340.jpg
# ['dataset/Mountain/', 'dataset/Summit/', 'dataset/Snow/', 'dataset/Winter/']
# Aufgenommen am 5.3.2022
# Collection/daffodil-7119341__340.jpg
# ['dataset/Aufgenommen am 5.3.2022/']
# Petit Minou Lighthouse, Lighthouse, Sea
# Collection/petit-minou-lighthouse-6582717__340.jpg
# ['dataset/Petit Minou Lighthouse/', 'dataset/Lighthouse/', 'dataset/Sea/']
# Forest, Twilight, Nature, Trees, Woods
# Collection/forest-3119826__480.jpg
# ['dataset/Forest/', 'dataset/Twilight/', 'dataset/Nature/', 'dataset/Trees/', 'dataset/Woods/']
# European Shorthair, Cat, Pet, Animal
# Collection/european-shorthair-7118037__340.jpg
# ['dataset/European Shorthair/', 'dataset/Cat/', 'dataset/Pet/', 'dataset/Animal/']
# Easter Bunny, Easter, Easter Festival
# Collection/easter-bunny-7126487__340.jpg
# ['dataset/Easter Bunny/', 'dataset/Easter/', 'dataset/Easter Festival/']
# Mountains, Meadow, Cabin, Clouds, Herb
# Collection/mountains-7097981__340.jpg
# ['dataset/Mountains/', 'dataset/Meadow/', 'dataset/Cabin/', 'dataset/Clouds/', 'dataset/Herb/']
# Buildings, Town, Road, Hills, Sunset
# Collection/buildings-6497337__340.jpg
# ['dataset/Buildings/', 'dataset/Town/', 'dataset/Road/', 'dataset/Hills/', 'dataset/Sunset/']
# City, Travel, Tourism, Mexico City
# Collection/city-7069010__340.jpg
# ['dataset/City/', 'dataset/Travel/', 'dataset/Tourism/', 'dataset/Mexico City/']
# Magnolia, Flower, Tree, Spring Flowers
# Collection/magnolia-7121115__340.jpg
# ['dataset/Magnolia/', 'dataset/Flower/', 'dataset/Tree/', 'dataset/Spring Flowers/']
# Donkey, Animal, Draft Animal, Mammal
# Collection/donkey-7124096__340.jpg
# ['dataset/Donkey/', 'dataset/Animal/', 'dataset/Draft Animal/', 'dataset/Mammal/']
# Aufgenommen am 20.3.2021
# Collection/weave-7119337__340.jpg
# ['dataset/Aufgenommen am 20.3.2021/']
# Fields, Nature, Landscape, Meadow, Rural
# Collection/fields-7121593__340.jpg
# ['dataset/Fields/', 'dataset/Nature/', 'dataset/Landscape/', 'dataset/Meadow/', 'dataset/Rural/']
# This is now the season for Cherry blossoms in Japan. Have you ever heard of “hanami”? We sit under the cherry trees and eat and drink with our friends.
# Collection/flowers-7119514__340.jpg
# ['dataset/This is now the season for Cherry blossoms in Japan. Have you ever heard of “hanami”? We sit under the cherry trees and eat and drink with our friends./']
# Error copying Collection/flowers-7119514__340.jpg to dataset/This is now the season for Cherry blossoms in Japan. Have you ever heard of “hanami”? We sit under the cherry trees and eat and drink with our friends./flowers-7119514__340.jpg: [Errno 22] Invalid argument: 'dataset/This is now the season for Cherry blossoms in Japan. Have you ever heard of “hanami”? We sit under the cherry trees and eat and drink with our friends./flowers-7119514__340.jpg'
# In einem kleinen Städtchen ...
# Collection/alley-7078098__340.jpg
# ['dataset/In einem kleinen Städtchen .../']
# Error copying Collection/alley-7078098__340.jpg to dataset/In einem kleinen Städtchen .../alley-7078098__340.jpg: [Errno 2] No such file or directory: 'dataset/In einem kleinen Städtchen .../alley-7078098__340.jpg'
# Drake, Waterbird, Wings
# Collection/drake-7114868__340.jpg
# ['dataset/Drake/', 'dataset/Waterbird/', 'dataset/Wings/']
# Pine Cone, Fir Green, Fir Branch
# Collection/pine-cone-6803226__340.jpg
# ['dataset/Pine Cone/', 'dataset/Fir Green/', 'dataset/Fir Branch/']
# Heron, Great Egret, River, Lake, Pond
# Collection/heron-6713611__340.jpg
# ['dataset/Heron/', 'dataset/Great Egret/', 'dataset/River/', 'dataset/Lake/', 'dataset/Pond/']
# Seagulls, Birds, Nature, Ocean, Sea, Sky
# Collection/seagulls-6690361__340.jpg
# ['dataset/Seagulls/', 'dataset/Birds/', 'dataset/Nature/', 'dataset/Ocean/', 'dataset/Sea/', 'dataset/Sky/']
# Mountains, Nature, Tourism, Hike, Alpine
# Collection/mountains-6486093__480.jpg
# ['dataset/Mountains/', 'dataset/Nature/', 'dataset/Tourism/', 'dataset/Hike/', 'dataset/Alpine/']
# Road, Mountain, Countryside, Landscape
# Collection/road-7110643__340.jpg
# ['dataset/Road/', 'dataset/Mountain/', 'dataset/Countryside/', 'dataset/Landscape/']
# Tree, Leaves, Autumn, Season, Nature
# Collection/tree-6786654__340.jpg
# ['dataset/Tree/', 'dataset/Leaves/', 'dataset/Autumn/', 'dataset/Season/', 'dataset/Nature/']
# Fantasy, Elf, Light, Plants, Bird Magic
# Collection/fantasy-7087606__340.jpg
# ['dataset/Fantasy/', 'dataset/Elf/', 'dataset/Light/', 'dataset/Plants/', 'dataset/Bird Magic/']
# Couple, Meadow, Walking, Nature, Sunset
# Collection/couple-7063784__340.jpg
# ['dataset/Couple/', 'dataset/Meadow/', 'dataset/Walking/', 'dataset/Nature/', 'dataset/Sunset/']
# Christmas, Background, Flat Lay
# Collection/christmas-1911637__340.jpg
# ['dataset/Christmas/', 'dataset/Background/', 'dataset/Flat Lay/']
# Blackthorn, Sloe, Winter, Prunus Spinosa
# Collection/blackthorn-7116000__340.jpg
# ['dataset/Blackthorn/', 'dataset/Sloe/', 'dataset/Winter/', 'dataset/Prunus Spinosa/']
# Boat, River, Forest, Landscape, Woods
# Collection/boat-6579441__340.jpg
# ['dataset/Boat/', 'dataset/River/', 'dataset/Forest/', 'dataset/Landscape/', 'dataset/Woods/']
# Walnuts, Nuts, Food, Healthy, Nutrition
# Collection/walnuts-7122043__340.jpg
# ['dataset/Walnuts/', 'dataset/Nuts/', 'dataset/Food/', 'dataset/Healthy/', 'dataset/Nutrition/']
# Climate Change, Protest, People
# Collection/climate-change-7127153__340.jpg
# ['dataset/Climate Change/', 'dataset/Protest/', 'dataset/People/']
# Mountains, Sunset, Germany, Fortress
# Collection/mountains-6531264__340.jpg
# ['dataset/Mountains/', 'dataset/Sunset/', 'dataset/Germany/', 'dataset/Fortress/']
# Candles, Candlelight, Christmas
# Collection/candles-6828695__340.jpg
# ['dataset/Candles/', 'dataset/Candlelight/', 'dataset/Christmas/']
# Flower, Butterfly, Fantasy, Spring
# Collection/flower-7022112__340.jpg
# ['dataset/Flower/', 'dataset/Butterfly/', 'dataset/Fantasy/', 'dataset/Spring/']
# Australian Wood Duck, Duck, Bird
# Collection/australian-wood-duck-7110865__340.jpg
# ['dataset/Australian Wood Duck/', 'dataset/Duck/', 'dataset/Bird/']
# Dog, Puppy, Pet, Cute, Doggy, Animal
# Collection/dog-6680642__340.jpg
# ['dataset/Dog/', 'dataset/Puppy/', 'dataset/Pet/', 'dataset/Cute/', 'dataset/Doggy/', 'dataset/Animal/']
# Cherry Blossom, Spring, Nature, Flowers
# Collection/cherry-blossom-7102224__340.jpg
# ['dataset/Cherry Blossom/', 'dataset/Spring/', 'dataset/Nature/', 'dataset/Flowers/']
# Christmas Tree, Holiday, Season
# Collection/christmas-tree-6895765__480.jpg
# ['dataset/Christmas Tree/', 'dataset/Holiday/', 'dataset/Season/']
# Sea Shell, Giant Conch
# Collection/sea-shell-6495338__340.jpg
# ['dataset/Sea Shell/', 'dataset/Giant Conch/']
# Paper, Crumpled, Texture, Shadows, Fold
# Collection/paper-5985445__340.jpg
# ['dataset/Paper/', 'dataset/Crumpled/', 'dataset/Texture/', 'dataset/Shadows/', 'dataset/Fold/']
# Bee, Pollination, Entomology, Macro
# Collection/bee-7103114__340.jpg
# ['dataset/Bee/', 'dataset/Pollination/', 'dataset/Entomology/', 'dataset/Macro/']
# Butterfly, Aurora Butterfly, Meadow
# Collection/butterfly-7114816__340.jpg
# ['dataset/Butterfly/', 'dataset/Aurora Butterfly/', 'dataset/Meadow/']
# 4 Weihnachtskerzen
# Collection/candles-6840499__340.jpg
# ['dataset/4 Weihnachtskerzen/']
# Add a description (optional)
# Collection/mute-swan-7115661__340.jpg
# ['dataset/Add a description (optional)/']
# Tulip, Spring, Flowering, Flower
# Collection/tulip-7120843__340.jpg
# ['dataset/Tulip/', 'dataset/Spring/', 'dataset/Flowering/', 'dataset/Flower/']
# Town, Countryside, Nature, Landscape
# Collection/town-7085835__340.jpg
# ['dataset/Town/', 'dataset/Countryside/', 'dataset/Nature/', 'dataset/Landscape/']
# El Hornero ( Furnarius rufus ) es una especie de ave paseriforme perteneciente a la familia de los furnáridos, y compone, junto con otras cinco especies el género Furnarius. El hornero es endémico de Sudamérica meridional y es el ave nacional de la República Argentina.
# Collection/birds-7124996__340.jpg
# ['dataset/El Hornero ( Furnarius rufus ) es una especie de ave paseriforme perteneciente a la familia de los furnáridos/', 'dataset/y compone/', 'dataset/junto con otras cinco especies el género Furnarius. El hornero es endémico de Sudamérica meridional y es el ave nacional de la República Argentina./']
# Cherry Blossom, Flowers, Spring, Sakura
# Collection/cherry-blossom-7113414__340.jpg
# ['dataset/Cherry Blossom/', 'dataset/Flowers/', 'dataset/Spring/', 'dataset/Sakura/']
# Fantasy, No Truth, Silence, Bound
# Collection/fantasy-7118471__340.jpg
# ['dataset/Fantasy/', 'dataset/No Truth/', 'dataset/Silence/', 'dataset/Bound/']
# Salad, Fruit, Berry, Healthy, Vitamins
# Collection/salad-7040875__340.jpg
# ['dataset/Salad/', 'dataset/Fruit/', 'dataset/Berry/', 'dataset/Healthy/', 'dataset/Vitamins/']
# Petit Minou Lighthouse, Lighthouse, Sea
# Collection/petit-minou-lighthouse-6759731__340.jpg
# ['dataset/Petit Minou Lighthouse/', 'dataset/Lighthouse/', 'dataset/Sea/']
# Easter Bunny, Easter, Easter Decorations
# Collection/easter-bunny-7126452__340.jpg
# ['dataset/Easter Bunny/', 'dataset/Easter/', 'dataset/Easter Decorations/']
# Bird, Heron, Ornithology, Species, Fauna
# Collection/bird-7122361__340.jpg
# ['dataset/Bird/', 'dataset/Heron/', 'dataset/Ornithology/', 'dataset/Species/', 'dataset/Fauna/']
# Shepherd'S-Purses, Capsella, Grass
# Collection/shepherds-purses-7104384__480.jpg
# ["dataset/Shepherd'S-Purses/", 'dataset/Capsella/', 'dataset/Grass/']
# Bernkastel-Kues, Germany, Cityscape
# Collection/bernkastel-kues-7117366__340.jpg
# ['dataset/Bernkastel-Kues/', 'dataset/Germany/', 'dataset/Cityscape/']
# Cherry Blossoms, Sakura, Flowers
# Collection/cherry-blossoms-6196363__340.jpg
# ['dataset/Cherry Blossoms/', 'dataset/Sakura/', 'dataset/Flowers/']
# Purple Flowers, Flowers, Pasqueflowers
# Collection/purple-flowers-7126569__340.jpg
# ['dataset/Purple Flowers/', 'dataset/Flowers/', 'dataset/Pasqueflowers/']
# Cyberpunk, Street, City, Platform
# Collection/cyberpunk-6061251__340.jpg
# ['dataset/Cyberpunk/', 'dataset/Street/', 'dataset/City/', 'dataset/Platform/']
# Leaves, Growth, Botany, Nature, Plant
# Collection/leaves-7099402__340.jpg
# ['dataset/Leaves/', 'dataset/Growth/', 'dataset/Botany/', 'dataset/Nature/', 'dataset/Plant/']
# Flower, Petals, Baby Rose
# Collection/flower-7123108__340.jpg
# ['dataset/Flower/', 'dataset/Petals/', 'dataset/Baby Rose/']
# Birds, Duck, Ornithology, Species, Fauna
# Collection/birds-7048729__340.jpg
# ['dataset/Birds/', 'dataset/Duck/', 'dataset/Ornithology/', 'dataset/Species/', 'dataset/Fauna/']
# Robin, Bird, Beak, Feathers, Plumage
# Collection/robin-7123932__340.jpg
# ['dataset/Robin/', 'dataset/Bird/', 'dataset/Beak/', 'dataset/Feathers/', 'dataset/Plumage/']
# Waves, Sea, Ocean, Beach, Blue Water
# Collection/waves-3473335__340.jpg
# ['dataset/Waves/', 'dataset/Sea/', 'dataset/Ocean/', 'dataset/Beach/', 'dataset/Blue Water/']
# Daffodil, Flower, Yellow Flower, Petals
# Collection/daffodil-7050408__340.jpg
# ['dataset/Daffodil/', 'dataset/Flower/', 'dataset/Yellow Flower/', 'dataset/Petals/']
# Bird, Yellow Warbler, Ornithology
# Collection/bird-7121805__340.jpg
# ['dataset/Bird/', 'dataset/Yellow Warbler/', 'dataset/Ornithology/']
# Leopard, Animal, Mammal, Big Cat
# Collection/leopard-7126525__340.jpg
# ['dataset/Leopard/', 'dataset/Animal/', 'dataset/Mammal/', 'dataset/Big Cat/']
# Honeybee, Sunflower, Pollination, Bee
# Collection/honeybee-6975865__340.jpg
# ['dataset/Honeybee/', 'dataset/Sunflower/', 'dataset/Pollination/', 'dataset/Bee/']
# Trees, Winter, Snow, White, Cold, Nature
# Collection/trees-4830285__340.jpg
# ['dataset/Trees/', 'dataset/Winter/', 'dataset/Snow/', 'dataset/White/', 'dataset/Cold/', 'dataset/Nature/']
# High in the French alps. Climbers walk the steep ridge of the valley blanche. The mountains are as dangerous as they are beautiful 👀 Chamonix Mont Blanc
# Collection/nature-6752035__480.jpg
# ['dataset/High in the French alps. Climbers walk the steep ridge of the valley blanche. The mountains are as dangerous as they are beautiful 👀 Chamonix Mont Blanc/']
# Couple, Silhouette, Love, Relationship
# Collection/couple-6548045__340.jpg
# ['dataset/Couple/', 'dataset/Silhouette/', 'dataset/Love/', 'dataset/Relationship/']
# Amsterdam, Dam Square, Child, Pigeons
# Collection/amsterdam-6823002__340.jpg
# ['dataset/Amsterdam/', 'dataset/Dam Square/', 'dataset/Child/', 'dataset/Pigeons/']
# Duck, Bird, Beak, Feathers, Plumage
# Collection/duck-7121326__340.jpg
# ['dataset/Duck/', 'dataset/Bird/', 'dataset/Beak/', 'dataset/Feathers/', 'dataset/Plumage/']
# Rice, Tomatoes, Food, Grain, Dish, Table
# Collection/rice-7122289__340.jpg
# ['dataset/Rice/', 'dataset/Tomatoes/', 'dataset/Food/', 'dataset/Grain/', 'dataset/Dish/', 'dataset/Table/']
# Trading, Blockchain, Cryptocurrency
# Collection/trading-6531134__340.jpg
# ['dataset/Trading/', 'dataset/Blockchain/', 'dataset/Cryptocurrency/']
# Stones, Rock, Balance, Balanced Rocks
# Collection/stones-6546233__340.jpg
# ['dataset/Stones/', 'dataset/Rock/', 'dataset/Balance/', 'dataset/Balanced Rocks/']
# Mountain, Snow, Sunrise, Peak, Summit
# Collection/mountain-6086083__340.jpg
# ['dataset/Mountain/', 'dataset/Snow/', 'dataset/Sunrise/', 'dataset/Peak/', 'dataset/Summit/']
# Forest, Nature, Trees, Woods, Outdoors
# Collection/forest-6589852__340.jpg
# ['dataset/Forest/', 'dataset/Nature/', 'dataset/Trees/', 'dataset/Woods/', 'dataset/Outdoors/']
# Bird, Robin, Ornithology, Species, Fauna
# Collection/bird-7109091__340.jpg
# ['dataset/Bird/', 'dataset/Robin/', 'dataset/Ornithology/', 'dataset/Species/', 'dataset/Fauna/']
# Mushrooms, Fungi, Mycology, Forest Floor
# Collection/mushrooms-7119658__340.jpg
# ['dataset/Mushrooms/', 'dataset/Fungi/', 'dataset/Mycology/', 'dataset/Forest Floor/']
# Crafting, Daisies, Vintage Aesthetic
# Collection/crafting-7117240__340.jpg
# ['dataset/Crafting/', 'dataset/Daisies/', 'dataset/Vintage Aesthetic/']
# Forest, Stars, Mountains, Night Sky
# Collection/forest-5442598__340.jpg
# ['dataset/Forest/', 'dataset/Stars/', 'dataset/Mountains/', 'dataset/Night Sky/']
# Sunset Street in Bavarian Alps
# Collection/street-6913633__340.jpg
# ['dataset/Sunset Street in Bavarian Alps/']
# Petals, Tree, Cherry, Garden, Blossom
# Collection/petals-7126056__480.jpg
# ['dataset/Petals/', 'dataset/Tree/', 'dataset/Cherry/', 'dataset/Garden/', 'dataset/Blossom/']
# Christmas, Christmas Tree, Presents
# Collection/christmas-1869902__340.jpg
# ['dataset/Christmas/', 'dataset/Christmas Tree/', 'dataset/Presents/']
# Squill, Flowers, Plant, Scilla
# Collection/squill-7094638__340.jpg
# ['dataset/Squill/', 'dataset/Flowers/', 'dataset/Plant/', 'dataset/Scilla/']
# Soap Bubbles, Colour, Macro, Pattern
# Collection/soap-bubbles-7113833__340.jpg
# ['dataset/Soap Bubbles/', 'dataset/Colour/', 'dataset/Macro/', 'dataset/Pattern/']
# Lavenders, Flowers, Lavender Field
# Collection/lavenders-6482952__340.jpg
# ['dataset/Lavenders/', 'dataset/Flowers/', 'dataset/Lavender Field/']
# Flowers, Lucile'S Glory Of The Snow
# Collection/flowers-7108857__340.jpg
# ['dataset/Flowers/', "dataset/Lucile'S Glory Of The Snow/"]
# Roses, Flowers, Yellow Flowers
# Collection/roses-6804169__340.jpg
# ['dataset/Roses/', 'dataset/Flowers/', 'dataset/Yellow Flowers/']
# Fuel, Gas Station, Refueling, Gas
# Collection/fuel-6999638__340.jpg
# ['dataset/Fuel/', 'dataset/Gas Station/', 'dataset/Refueling/', 'dataset/Gas/']
# Peace, Peace Sign, Against War, Ukraine
# Collection/peace-7121863__340.jpg
# ['dataset/Peace/', 'dataset/Peace Sign/', 'dataset/Against War/', 'dataset/Ukraine/']
# Lake, Mountains, Nature, Dusk, To Travel
# Collection/lake-7080525__340.jpg
# ['dataset/Lake/', 'dataset/Mountains/', 'dataset/Nature/', 'dataset/Dusk/', 'dataset/To Travel/']
# Peach Blossom, Flowers, Branch, Tree
# Collection/peach-blossom-7115080__340.jpg
# ['dataset/Peach Blossom/', 'dataset/Flowers/', 'dataset/Branch/', 'dataset/Tree/']
# Honey Bee, Bee, Flowers, Insect, Tansy
# Collection/honey-bee-6506809__340.jpg
# ['dataset/Honey Bee/', 'dataset/Bee/', 'dataset/Flowers/', 'dataset/Insect/', 'dataset/Tansy/']
# Flower, Anemone, Spring, Blue, Nature
# Collection/flower-7120281__340.jpg
# ['dataset/Flower/', 'dataset/Anemone/', 'dataset/Spring/', 'dataset/Blue/', 'dataset/Nature/']
# Magnolia, Bud, Flower, Plant, Shrub
# Collection/magnolia-7120880__340.jpg
# ['dataset/Magnolia/', 'dataset/Bud/', 'dataset/Flower/', 'dataset/Plant/', 'dataset/Shrub/']
# Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…
# Collection/giant-lily-7114512__340.jpg
# ['dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/']
# 313it [00:00, 623.34it/s]
# Error copying Collection/giant-lily-7114512__340.jpg to dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/giant-lily-7114512__340.jpg: [Errno 2] No such file or directory: 'dataset/Dorianthes Palmeri. 3 meters high. Makes her first flower at 40 years. Blooms only once in her life and dies... ***************************** Dorianthes Palmeri. 3 Meter hoch. Macht ihre erste Blume nach 40 Jahren. Blüht nur einmal in ihrem Leben und stirbt…/giant-lily-7114512__340.jpg'
# Rufous, Bird, Hummingbird, Flight, Wings
# Collection/rufous-6476117__480.jpg
# ['dataset/Rufous/', 'dataset/Bird/', 'dataset/Hummingbird/', 'dataset/Flight/', 'dataset/Wings/']
# Ginkgo, Leaf, Dew, Dewdrops, Raindrops
# Collection/ginkgo-6350293__340.jpg
# ['dataset/Ginkgo/', 'dataset/Leaf/', 'dataset/Dew/', 'dataset/Dewdrops/', 'dataset/Raindrops/']
# Lantern, Festival, Decoration
# Collection/lantern-6939870__340.jpg
# ['dataset/Lantern/', 'dataset/Festival/', 'dataset/Decoration/']
# Paris, City, Cloudy Day, Stormy Day
# Collection/paris-6803796__340.jpg
# ['dataset/Paris/', 'dataset/City/', 'dataset/Cloudy Day/', 'dataset/Stormy Day/']
# Animal, Hamadryas Baboon, Baboon
# Collection/animal-7121622__340.jpg
# ['dataset/Animal/', 'dataset/Hamadryas Baboon/', 'dataset/Baboon/']
# Pets, Cute, Cat, Dog, Cute Wallpaper
# Collection/pets-3715733__340.jpg
# ['dataset/Pets/', 'dataset/Cute/', 'dataset/Cat/', 'dataset/Dog/', 'dataset/Cute Wallpaper/']
# Travel, Airport, Boarding Pass, Boarding
# Collection/travel-5219496__340.jpg
# ['dataset/Travel/', 'dataset/Airport/', 'dataset/Boarding Pass/', 'dataset/Boarding/']
# Portret van de lente
# Collection/valley-7118324__340.jpg
# ['dataset/Portret van de lente/']
# Ribbon, Bow, Gift, Decoration, Colorful
# Collection/ribbon-7115324__340.png
# ['dataset/Ribbon/', 'dataset/Bow/', 'dataset/Gift/', 'dataset/Decoration/', 'dataset/Colorful/']
# Cows, Cattle, Livestock, Farm Animals
# Collection/cows-7104262__340.jpg
# ['dataset/Cows/', 'dataset/Cattle/', 'dataset/Livestock/', 'dataset/Farm Animals/']
# Photographed on 29-03-22 in the Amstelpark.
# Collection/glory-of-the-snow-7105247__340.jpg
# ['dataset/Photographed on 29-03-22 in the Amstelpark./']
# Animal, Dog, Canine, Mammal, Breed, Pet
# Collection/animal-7118858__340.jpg
# ['dataset/Animal/', 'dataset/Dog/', 'dataset/Canine/', 'dataset/Mammal/', 'dataset/Breed/', 'dataset/Pet/']
# Tulips, Flowers, Blossom, Petals, Bloom
# Collection/tulips-7058127__340.jpg
# ['dataset/Tulips/', 'dataset/Flowers/', 'dataset/Blossom/', 'dataset/Petals/', 'dataset/Bloom/']
# Meadowsweet, Flowers, Plant
# Collection/meadowsweet-7126754__340.jpg
# ['dataset/Meadowsweet/', 'dataset/Flowers/', 'dataset/Plant/']
# Floral Background, Scrapbooking
# Collection/floral-background-6951261__480.jpg
# ['dataset/Floral Background/', 'dataset/Scrapbooking/']
# Nature, Sea, Sunset, Water, Mood, Ocean
# Collection/nature-7113818__340.jpg
# ['dataset/Nature/', 'dataset/Sea/', 'dataset/Sunset/', 'dataset/Water/', 'dataset/Mood/', 'dataset/Ocean/']
# Nutrition, Market, Corn, Organic, Fresh
# ...
# ['dataset/Board/', 'dataset/Heart/', 'dataset/Game/', 'dataset/Past/', 'dataset/Love/', 'dataset/Off/']
# To Travel, Mountains, Vacation
# Collection/travel-5410070__340.jpg
# ['dataset/To Travel/', 'dataset/Mountains/', 'dataset/Vacation/']
# Rider, Helmet, Motorcycle Gear
# Collection/rider-6796556__340.jpg
# ['dataset/Rider/', 'dataset/Helmet/', 'dataset/Motorcycle Gear/']
# Flower, Hydrangea, Bloom, Petals
# Collection/flower-7002381__340.jpg
# ['dataset/Flower/', 'dataset/Hydrangea/', 'dataset/Bloom/', 'dataset/Petals/']
# Dahlia, Dahlia Flower, Petals, Flower
# Collection/dahlia-6638241__340.jpg
# ['dataset/Dahlia/', 'dataset/Dahlia Flower/', 'dataset/Petals/', 'dataset/Flower/']
# Plant, Little Plants, Sow, Grow
# Collection/plant-4036191__340.jpg
# ['dataset/Plant/', 'dataset/Little Plants/', 'dataset/Sow/', 'dataset/Grow/']
# Church, Puddle, Reflection, Pavement
# Collection/church-6933563__340.jpg
# ['dataset/Church/', 'dataset/Puddle/', 'dataset/Reflection/', 'dataset/Pavement/']
# Mountain, Nature, Tree, Forest, Fog
# Collection/mountain-4242391__340.jpg
# ['dataset/Mountain/', 'dataset/Nature/', 'dataset/Tree/', 'dataset/Forest/', 'dataset/Fog/']
# Town, Travel, Tourism, Historical
# Collection/town-6538728__340.jpg
# ['dataset/Town/', 'dataset/Travel/', 'dataset/Tourism/', 'dataset/Historical/']
# Every donation goes to Aljona, Sasha and Christina, who survived Mariupol for 5 weeks and are now finally on their way to me in Germany. Спасибі
# Collection/railroad-tracks-6954582__340.jpg
# ['dataset/Every donation goes to Aljona/', 'dataset/Sasha and Christina/', 'dataset/who survived Mariupol for 5 weeks and are now finally on their way to me in Germany. Спасибі/']
# Cat, Black Cat, Yellow Eyes, Black Cat
# Collection/cat-2540940__340.jpg
# ['dataset/Cat/', 'dataset/Black Cat/', 'dataset/Yellow Eyes/', 'dataset/Black Cat/']
# Sea, Beach, Rocks, Coast, Shore, Stones
# Collection/sea-6959341__340.jpg
# ['dataset/Sea/', 'dataset/Beach/', 'dataset/Rocks/', 'dataset/Coast/', 'dataset/Shore/', 'dataset/Stones/']
# Valentine'S Day, Flowers, Book
# Collection/valentines-day-6935731__340.jpg
# ["dataset/Valentine'S Day/", 'dataset/Flowers/', 'dataset/Book/']
# Ruins, Abandoned, Hill, Dusk, Mysterious
# Collection/ruins-5508421__480.jpg
# ['dataset/Ruins/', 'dataset/Abandoned/', 'dataset/Hill/', 'dataset/Dusk/', 'dataset/Mysterious/']
# Trees, Birds, Forest, Lake, Branches
# Collection/trees-6882431__340.jpg
# ['dataset/Trees/', 'dataset/Birds/', 'dataset/Forest/', 'dataset/Lake/', 'dataset/Branches/']
# Sea, Nature, Sunset, Lake, Ammersee
# Collection/sea-6760936__340.jpg
# ['dataset/Sea/', 'dataset/Nature/', 'dataset/Sunset/', 'dataset/Lake/', 'dataset/Ammersee/']
# Ape, Chimp, Primate, Monkey, Animal
# Collection/ape-6848948__340.jpg
# ['dataset/Ape/', 'dataset/Chimp/', 'dataset/Primate/', 'dataset/Monkey/', 'dataset/Animal/']
# Guitar, Fingerboard, Acoustic Guitar
# Collection/guitar-6313627__340.jpg
# ['dataset/Guitar/', 'dataset/Fingerboard/', 'dataset/Acoustic Guitar/']
# Competence, Experience, Hand
# Collection/competence-2741773__340.jpg
# ['dataset/Competence/', 'dataset/Experience/', 'dataset/Hand/']
# Quarry, Canyon, Mining, Sandstone
# Collection/quarry-6655939__340.jpg
# ['dataset/Quarry/', 'dataset/Canyon/', 'dataset/Mining/', 'dataset/Sandstone/']
# Flower, Nature, Plant, Flowering Stems
# Collection/flower-5230513__340.jpg
# ['dataset/Flower/', 'dataset/Nature/', 'dataset/Plant/', 'dataset/Flowering Stems/']
# Bird, Pigeon, Dove, Plumage, Perched
# Collection/bird-6899268__340.jpg
# ['dataset/Bird/', 'dataset/Pigeon/', 'dataset/Dove/', 'dataset/Plumage/', 'dataset/Perched/']
# Sparkler, Firework, Celebrate
# Collection/sparkler-1835387__340.jpg
# ['dataset/Sparkler/', 'dataset/Firework/', 'dataset/Celebrate/']
# Girl, Bikini, Beach, Summer, Holiday
# Collection/girl-622534__340.jpg
# ['dataset/Girl/', 'dataset/Bikini/', 'dataset/Beach/', 'dataset/Summer/', 'dataset/Holiday/']
# Run, Boy, Outdoor, Be Human, Handsome
# Collection/school-1822566__340.jpg
# ['dataset/Run/', 'dataset/Boy/', 'dataset/Outdoor/', 'dataset/Be Human/', 'dataset/Handsome/']
# Mountains, Sunlight, Alps, Nature
# Collection/mountains-6753786__340.jpg
# ['dataset/Mountains/', 'dataset/Sunlight/', 'dataset/Alps/', 'dataset/Nature/']
# Nature, Colorado, Waterfall, Trail
# Collection/nature-7083481__340.jpg
# ['dataset/Nature/', 'dataset/Colorado/', 'dataset/Waterfall/', 'dataset/Trail/']
# Pumpkin, Vegetables, Fall, Food, Healthy
# Collection/pumpkin-6667899__480.jpg
# ['dataset/Pumpkin/', 'dataset/Vegetables/', 'dataset/Fall/', 'dataset/Food/', 'dataset/Healthy/']
# Tractor, Sunset, Landscape, Field
# Collection/tractor-4894284__340.jpg
# ['dataset/Tractor/', 'dataset/Sunset/', 'dataset/Landscape/', 'dataset/Field/']
# A Book, Isolated, Book Cover, Empty
# Collection/book-3088777__340.png
# ['dataset/A Book/', 'dataset/Isolated/', 'dataset/Book Cover/', 'dataset/Empty/']
# Ceiling, Dome, Glass, Stained Glass
# Collection/ceiling-5044915__340.jpg
# ['dataset/Ceiling/', 'dataset/Dome/', 'dataset/Glass/', 'dataset/Stained Glass/']
# Mountains, Switzerland, Bauen
# Collection/mountains-7058291__340.jpg
# ['dataset/Mountains/', 'dataset/Switzerland/', 'dataset/Bauen/']
# Dog, Puppy, Sleeping, Pet, Animal
# Collection/dog-6677765__340.jpg
# ['dataset/Dog/', 'dataset/Puppy/', 'dataset/Sleeping/', 'dataset/Pet/', 'dataset/Animal/']
# Paragraph, A Book, Law, Laws, Read
# Collection/clause-2546124__340.jpg
# ['dataset/Paragraph/', 'dataset/A Book/', 'dataset/Law/', 'dataset/Laws/', 'dataset/Read/']
# Jewellery, Gems, Gold, Jewels, Diamonds
# Collection/jewellery-4779095__340.jpg
# ['dataset/Jewellery/', 'dataset/Gems/', 'dataset/Gold/', 'dataset/Jewels/', 'dataset/Diamonds/']
# Colonnade, Building, Architecture
# Collection/colonnade-7013100__340.jpg
# ['dataset/Colonnade/', 'dataset/Building/', 'dataset/Architecture/']
# Bird, Humboldt Penguin, Ornithology
# Collection/bird-7045844__340.jpg
# ['dataset/Bird/', 'dataset/Humboldt Penguin/', 'dataset/Ornithology/']
# Balloons, Celebration, Congratulation
# Collection/balloons-2826093__340.jpg
# ['dataset/Balloons/', 'dataset/Celebration/', 'dataset/Congratulation/']
# Band, Carnival, Lucerne, Switzerland
# Collection/band-7047907__340.jpg
# ['dataset/Band/', 'dataset/Carnival/', 'dataset/Lucerne/', 'dataset/Switzerland/']
# Landscape, Beautiful, Sunset, Sky
# Collection/landscape-5276688__340.jpg
# ['dataset/Landscape/', 'dataset/Beautiful/', 'dataset/Sunset/', 'dataset/Sky/']
# Cat, Feline, Whiskers, Garden, Pet
# Collection/cat-6559810__340.jpg
# ['dataset/Cat/', 'dataset/Feline/', 'dataset/Whiskers/', 'dataset/Garden/', 'dataset/Pet/']
# Christmas, Child, Christmas Motif
# Collection/christmas-2947668__340.jpg
# ['dataset/Christmas/', 'dataset/Child/', 'dataset/Christmas Motif/']
# French Bulldog, Dog, Animal Portrait
# Collection/french-bulldog-4278114__480.jpg
# ['dataset/French Bulldog/', 'dataset/Dog/', 'dataset/Animal Portrait/']
# Flower, Blossoms, Daisy, Summer
# Collection/flower-2947858__340.png
# ['dataset/Flower/', 'dataset/Blossoms/', 'dataset/Daisy/', 'dataset/Summer/']
# Christmas, Third Advent, Advent
# Collection/christmas-3884563__340.jpg
# ['dataset/Christmas/', 'dataset/Third Advent/', 'dataset/Advent/']
# Trees, Nature, Pond, Monochrome
# Collection/trees-6774588__340.jpg
# ['dataset/Trees/', 'dataset/Nature/', 'dataset/Pond/', 'dataset/Monochrome/']
# Animal, Cat, Feline, Mammal, Fur
# Collection/animal-6929146__340.jpg
# ['dataset/Animal/', 'dataset/Cat/', 'dataset/Feline/', 'dataset/Mammal/', 'dataset/Fur/']
# Pancakes, Yummy, Dessert, Enjoy The Meal
# Collection/pancakes-4410606__340.jpg
# ['dataset/Pancakes/', 'dataset/Yummy/', 'dataset/Dessert/', 'dataset/Enjoy The Meal/']
# Fishermen, Vietnam, Go Fishing, Beach
# Collection/the-fishermen-3039591__340.jpg
# ['dataset/Fishermen/', 'dataset/Vietnam/', 'dataset/Go Fishing/', 'dataset/Beach/']
# Peacock Feather, Macro, Peacock, Bird
# Collection/peacock-feather-3030306__340.jpg
# ['dataset/Peacock Feather/', 'dataset/Macro/', 'dataset/Peacock/', 'dataset/Bird/']
# Lotus, Flower, Dew, Wet, Dewdrops, Plant
# Collection/lotus-6643427__340.jpg
# ['dataset/Lotus/', 'dataset/Flower/', 'dataset/Dew/', 'dataset/Wet/', 'dataset/Dewdrops/', 'dataset/Plant/']
# Honey Bees, Bees, Flowers, Insects
# Collection/honey-bees-6709477__340.jpg
# ['dataset/Honey Bees/', 'dataset/Bees/', 'dataset/Flowers/', 'dataset/Insects/']
# Buildings, City, Illuminated
# Collection/buildings-936589__340.jpg
# ['dataset/Buildings/', 'dataset/City/', 'dataset/Illuminated/']
# Planet, Ball-Shaped, Universe, Science
# Collection/planet-3063614__340.jpg
# ['dataset/Planet/', 'dataset/Ball-Shaped/', 'dataset/Universe/', 'dataset/Science/']
# Canal, Water, Rice, Field, Paddy, Man
# Collection/canal-3897510__340.jpg
# ['dataset/Canal/', 'dataset/Water/', 'dataset/Rice/', 'dataset/Field/', 'dataset/Paddy/', 'dataset/Man/']
# Pagoda, Buildings, Chinese Roof
# Collection/pagoda-6598099__340.jpg
# ['dataset/Pagoda/', 'dataset/Buildings/', 'dataset/Chinese Roof/']
# Black-Tailed Godwit, Bird, Avian
# Collection/black-tailed-godwit-6977034__340.jpg
# ['dataset/Black-Tailed Godwit/', 'dataset/Bird/', 'dataset/Avian/']
# Animal, Cat, Mammal, Feline, Pet
# Collection/animal-6622543__480.jpg
# ['dataset/Animal/', 'dataset/Cat/', 'dataset/Mammal/', 'dataset/Feline/', 'dataset/Pet/']
# Error, Not Found, 404, Lego, Mistake, 4
# Collection/error-2129569__340.jpg
# ['dataset/Error/', 'dataset/Not Found/', 'dataset/404/', 'dataset/Lego/', 'dataset/Mistake/', 'dataset/4/']
# Sea, Road, Street Lights, Coast, Ocean
# Collection/sea-6468902__340.jpg
# ['dataset/Sea/', 'dataset/Road/', 'dataset/Street Lights/', 'dataset/Coast/', 'dataset/Ocean/']
# Drought, a consequence of global warming, puts wildlife at risk.
# Collection/red-fox-6310401__340.jpg
# ['dataset/Drought/', 'dataset/a consequence of global warming/', 'dataset/puts wildlife at risk./']
# Mock Oranges, Mock Oranges Blossoms
# Collection/mock-oranges-7034520__340.jpg
# ['dataset/Mock Oranges/', 'dataset/Mock Oranges Blossoms/']
# Photographer, Man, Camera, Beach, Sea
# Collection/photographer-1867417__340.jpg
# ['dataset/Photographer/', 'dataset/Man/', 'dataset/Camera/', 'dataset/Beach/', 'dataset/Sea/']
# Scooter, Vespa, Isolated, Trinket
# Collection/motor-scooter-3655011__340.png
# ['dataset/Scooter/', 'dataset/Vespa/', 'dataset/Isolated/', 'dataset/Trinket/']
# Relaxing, Loungers, Pool Side
# Collection/relaxing-3112750__340.jpg
# ['dataset/Relaxing/', 'dataset/Loungers/', 'dataset/Pool Side/']
# Composition, art!
# Collection/art-gallery-3909660__340.jpg
# ['dataset/Composition/', 'dataset/art!/']
# Owl, Bird, Animal, Bird Of Prey
# Collection/owl-6840128__340.jpg
# ['dataset/Owl/', 'dataset/Bird/', 'dataset/Animal/', 'dataset/Bird Of Prey/']
# Child, Bike, Wheel, Girl, Speed, Road
# Collection/child-7090386__340.jpg
# ['dataset/Child/', 'dataset/Bike/', 'dataset/Wheel/', 'dataset/Girl/', 'dataset/Speed/', 'dataset/Road/']
# Macbook, Laptop, Computer, Technology
# Collection/macbook-926425__340.jpg
# ['dataset/Macbook/', 'dataset/Laptop/', 'dataset/Computer/', 'dataset/Technology/']
# Boxing, Boxers, Boxing Ring, Sports
# Collection/boxing-6771970__340.jpg
# ['dataset/Boxing/', 'dataset/Boxers/', 'dataset/Boxing Ring/', 'dataset/Sports/']
# Exterior, Home, House, Luxury
# Collection/exterior-1597098__340.jpg
# ['dataset/Exterior/', 'dataset/Home/', 'dataset/House/', 'dataset/Luxury/']
# Laughing, One Person, Barefoot
# Collection/laughing-5582975__340.jpg
# ['dataset/Laughing/', 'dataset/One Person/', 'dataset/Barefoot/']
# Landscape, Birch Trees, Trees, Lake
# Collection/landscape-2577207__340.jpg
# ['dataset/Landscape/', 'dataset/Birch Trees/', 'dataset/Trees/', 'dataset/Lake/']
# Meat, Beef, Food, Raw, Fresh, Ingredient
# Collection/meat-6393396__340.jpg
# ['dataset/Meat/', 'dataset/Beef/', 'dataset/Food/', 'dataset/Raw/', 'dataset/Fresh/', 'dataset/Ingredient/']
# Book Cover, Culture, Antique, Ganesha
# Collection/book-cover-4397758__340.jpg
# ['dataset/Book Cover/', 'dataset/Culture/', 'dataset/Antique/', 'dataset/Ganesha/']
# Rooster, Brahma, Chicken, Animal
# Collection/rooster-6978340__340.jpg
# ['dataset/Rooster/', 'dataset/Brahma/', 'dataset/Chicken/', 'dataset/Animal/']
# Bengal Cat, Cat, Pet, Feline, Animal
# Collection/bengal-cat-6727376__340.jpg
# ['dataset/Bengal Cat/', 'dataset/Cat/', 'dataset/Pet/', 'dataset/Feline/', 'dataset/Animal/']
# Grapefruits, Half, Fruits, Cross Section
# Collection/grapefruits-5892709__340.jpg
# ['dataset/Grapefruits/', 'dataset/Half/', 'dataset/Fruits/', 'dataset/Cross Section/']
# Halloween, Pumpkin, Leaves, Fall, Autumn
# Collection/halloween-6755686__340.jpg
# ['dataset/Halloween/', 'dataset/Pumpkin/', 'dataset/Leaves/', 'dataset/Fall/', 'dataset/Autumn/']
# Street Performance, Group, Band, Music
# Collection/street-performance-6538895__340.jpg
# ['dataset/Street Performance/', 'dataset/Group/', 'dataset/Band/', 'dataset/Music/']
# City, Village, Europe, To Travel
# Collection/city-6806148__340.jpg
# ['dataset/City/', 'dataset/Village/', 'dataset/Europe/', 'dataset/To Travel/']
# Flower, Flora, Nature, Hibiscus
# Collection/flower-6889383__340.jpg
# ['dataset/Flower/', 'dataset/Flora/', 'dataset/Nature/', 'dataset/Hibiscus/']
# Horse, Animal, Mammal, Equine, Head, Eye
# Collection/horse-4982702__340.jpg
# ['dataset/Horse/', 'dataset/Animal/', 'dataset/Mammal/', 'dataset/Equine/', 'dataset/Head/', 'dataset/Eye/']
# Treasure Chest, Chest, Jewellery, Open
# Collection/treasure-chest-619868__340.jpg
# ['dataset/Treasure Chest/', 'dataset/Chest/', 'dataset/Jewellery/', 'dataset/Open/']
# Children, Slums, Poverty, Poor, Child
# Collection/children-2876359__340.jpg
# ['dataset/Children/', 'dataset/Slums/', 'dataset/Poverty/', 'dataset/Poor/', 'dataset/Child/']
# Flamingos, Bathing, Birds, Water
# Collection/flamingos-5819380__340.jpg
# ['dataset/Flamingos/', 'dataset/Bathing/', 'dataset/Birds/', 'dataset/Water/']
# Farmland, Winter, Snow, Stormy, Idaho
# Collection/farmland-6867651__340.jpg
# ['dataset/Farmland/', 'dataset/Winter/', 'dataset/Snow/', 'dataset/Stormy/', 'dataset/Idaho/']
# Darling, Clouds, Shapes, Blue, Weather
# Collection/sky-5274530__340.jpg
# ['dataset/Darling/', 'dataset/Clouds/', 'dataset/Shapes/', 'dataset/Blue/', 'dataset/Weather/']
# 9093it [00:17, 531.64it/s]
# Kings College, Cambridge, Uk, University
# Collection/kings-college-3889124__340.jpg
# ['dataset/Kings College/', 'dataset/Cambridge/', 'dataset/Uk/', 'dataset/University/']
# Night View, Seoul, Korea, Han River
# Collection/night-view-3538984__340.jpg
# ['dataset/Night View/', 'dataset/Seoul/', 'dataset/Korea/', 'dataset/Han River/']
# Bride, Wedding Dress, Model, Asian
# Collection/bride-6281458__340.jpg
# ['dataset/Bride/', 'dataset/Wedding Dress/', 'dataset/Model/', 'dataset/Asian/']
# Italy, Venice, Gondolas, Sunset, Boats
# Collection/italy-6887243__340.jpg
# ['dataset/Italy/', 'dataset/Venice/', 'dataset/Gondolas/', 'dataset/Sunset/', 'dataset/Boats/']
# Wall, Wood, Background, Old
# Collection/wall-6653365__340.jpg
# ['dataset/Wall/', 'dataset/Wood/', 'dataset/Background/', 'dataset/Old/']
# The Nun, Movie, Horror, Nun, Strange
# Collection/the-nun-3796613__340.jpg
# ['dataset/The Nun/', 'dataset/Movie/', 'dataset/Horror/', 'dataset/Nun/', 'dataset/Strange/']
# Fruit, Tomatoes, Biological, Ripe, Food
# Collection/fruit-6857879__340.jpg
# ['dataset/Fruit/', 'dataset/Tomatoes/', 'dataset/Biological/', 'dataset/Ripe/', 'dataset/Food/']
# Girl, Bonnet, Portrait, Happy, Caucasian
# Collection/girl-204327__340.jpg
# ['dataset/Girl/', 'dataset/Bonnet/', 'dataset/Portrait/', 'dataset/Happy/', 'dataset/Caucasian/']
# Pear, Fruit, Food, Background, Healthy
# Collection/pear-3070020__340.png
# ['dataset/Pear/', 'dataset/Fruit/', 'dataset/Food/', 'dataset/Background/', 'dataset/Healthy/']
# Ants, Insects, Plants, Flowers, Animal
# Collection/ants-6645412__480.jpg
# ['dataset/Ants/', 'dataset/Insects/', 'dataset/Plants/', 'dataset/Flowers/', 'dataset/Animal/']
# Flower, Flora, Garden, Nature
# Collection/flower-6926320__340.jpg
# ['dataset/Flower/', 'dataset/Flora/', 'dataset/Garden/', 'dataset/Nature/']
# Kara Dag Mountain, Resort Village, Town
# Collection/kara-dag-mountain-6535841__340.jpg
# ['dataset/Kara Dag Mountain/', 'dataset/Resort Village/', 'dataset/Town/']
# Island, Lake, Fog, Forest, Nature
# Collection/island-6676628__340.jpg
# ['dataset/Island/', 'dataset/Lake/', 'dataset/Fog/', 'dataset/Forest/', 'dataset/Nature/']

# %%
len(os.listdir('dataset'))
# Out:
# 7970

# %%
folder_ = []
freq    = []

for folder in tqdm(os.listdir('dataset')):
    
    try:
        freq.append(len(os.listdir('Dataset/' + folder)))
        folder_.append(folder)

    except:
        pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7970/7970 [00:00<00:00, 45291.24it/s]

# %%
df_ = pd.DataFrame()

df_['folder'] = folder_
df_['freq']   = freq

df_.sort_values(by = 'freq', ascending = False).head(10)
# Out:
#          folder  freq
# 4747     nature   838
# 226      Animal   608
# 2744     Flower   548
# 727        Bird   517
# 2760    Flowers   505
# 6096        Sea   305
# 5348      Plant   283
# 6777     Sunset   275
# 2811     Forest   261
# 3989  Landscape   242

# %%
df_.sort_values(by = 'freq', ascending = True).head(10)
# Out:
#                                                  folder  freq
# 2282                              Each candle is a soul     0
# 2004                                Das versteckte Haus     0
# 2048                                 Der Sonne entgegen     0
# 2086                                   die hinauf führt     0
# 3657                         In einem kleinen Städtchen     0
# 2559  Fantasmagòrica vista de los Reyes Magos de Ori...     0
# 2387                                         emergiendo     0
# 4686                                    Music Wallpaper     1
# 4684                                        Music Notes     1
# 4683                                       Music Melody     1
